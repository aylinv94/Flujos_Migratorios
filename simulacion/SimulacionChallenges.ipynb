# %%
import random
from faker import Faker
from datetime import datetime, timedelta
from random import choice, choices
import csv
import pandas as pd

# %%
# fake = Faker()

# class ONG:
#     def __init__(self):
#         self.pool_challenges = []
#         self.personas = []

#     def crear_challenge(self):
#         challenge = Challenge()
#         self.pool_challenges.append(challenge)
#         return challenge

#     def agregar_persona(self, persona):
#         self.personas.append(persona)

#     def remover_challenge(self, challenge):
#         if challenge in self.pool_challenges:
#             self.pool_challenges.remove(challenge)
#         else:
#             print("El challenge ya no está en la lista.")

#     def remover_persona(self, persona):
#         if persona in self.personas:
#             self.personas.remove(persona)
#         else:
#             print("La persona ya no está en la lista.")

#     def __str__(self):
#         participantes = "\n".join([f"{p.nombre} {p.apellido}" for p in self.personas])
#         return f"Challenges: {[challenge.id_challenge for challenge in self.pool_challenges]}\nParticipantes:\n{participantes}"

# class Challenge:
#     siguiente_id = 0

#     def __init__(self):
#         Challenge.siguiente_id += 1
#         self.id_challenge = Challenge.siguiente_id
#         self.participantes = []

#     def agregar_participante(self, participante):
#         if isinstance(participante, Persona):
#             self.participantes.append(participante)
#         else:
#             raise ValueError("Solo se pueden agregar objetos de la clase Persona como participantes.")

#     def __str__(self):
#         return f"Id challenge: {self.id_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}"

# class Persona:
#     def __init__(self):
#         self.nombre = fake.first_name()
#         self.apellido = fake.last_name()
#         self.nacionalidad = fake.country()
        
#     def __str__(self):
#         return f"{self.nombre} {self.apellido}\nNacionalidad: {self.nacionalidad}"

# class CreadorDeChallenge(Persona):
#     def __init__(self, ong):
#         super().__init__()
#         self.challenge_creado = ong.crear_challenge()
#         self.challenge_creado.agregar_participante(self)
#         ong.agregar_persona(self)
        
#     def nombre_apellido(self):
#         return f"{self.nombre} {self.apellido}"    

#     def __str__(self):
#         return f"Nombre: {self.challenge_creado}\nApellido: {self.apellido}\nNacionalidad: {self.nacionalidad}"    

# class Seguidor(Persona):
#     def __init__(self):
#         super().__init__()
#         self.challenges = []

#     def unirse_challenge(self, challenge):
#         if challenge in self.challenges:
#             print("Ya te uniste a este challenge.")
#         else:
#             challenge.agregar_participante(self)
#             self.challenges.append(challenge)

#     def nombre_apellido(self):
#         return f"{self.nombre} {self.apellido}"

#     def buscar_challenges(self, lista_challenges):
#         for challenge in lista_challenges:
#             print(f"Challenge {challenge.numero}: {len(challenge.participantes)} participantes.")

#     def unirse_challenge_aleatorio(self, ong):
#         challenges = ong.pool_challenges
#         n_challenges = len(challenges)
#         if n_challenges == 0:
#             print("No hay challenges disponibles.")
#             return
#         idx = random.randint(0, n_challenges-1)
#         challenge = challenges[idx]
#         self.unirse_challenge(challenge)

# %%
# fake = Faker()

# class ONG:
#     def __init__(self):
#         self.challenges_activos = []
#         self.personas = []
#         self.challenges_exitosos = []
#         self.challenges_discontinuados = []

#     def crear_challenge(self):
#         rand = random.random()
#         if rand < 0.7:
#             challenge = Donacion()
#         elif rand < 0.87:
#             challenge = VoluntariadoPresencial()
#         elif rand < 0.93:
#             challenge = VoluntariadoTraductor()    
#         elif rand < 0.98:
#             challenge = VoluntariadoAbogado()
#         else:
#             challenge = Challenge()
#         self.challenges_activos.append(challenge)
#         return challenge


#     def agregar_persona(self, persona):
#         self.personas.append(persona)

#     def remover_challenge(self, challenge):
#         if challenge in self.challenges_activos:
#             self.challenges_activos.remove(challenge)
#         else:
#             print("El challenge ya no está en la lista.")

#     def remover_persona(self, persona):
#         if persona in self.personas:
#             self.personas.remove(persona)
#         else:
#             print("La persona ya no está en la lista.")

#     def mover_challenge_exitoso(self, challenge):
#         if challenge in self.challenges_activos:
#             self.challenges_activos.remove(challenge)
#             self.challenges_exitosos.append(challenge)
#         else:
#             print("El challenge no está activo.")

#     def mover_challenge_discontinuado(self, challenge):
#         if challenge in self.challenges_activos:
#             self.challenges_activos.remove(challenge)
#             self.challenges_discontinuados.append(challenge)
#         else:
#             print("El challenge no está activo.")
            
#     def discontinuar_todos(self):
#         for challenge in self.challenges_activos:
#             self.mover_challenge_discontinuado(challenge)
#         self.challenges_activos = []

#     def __str__(self):
#         participantes = "\n".join([f"{p.nombre} {p.apellido}" for p in self.personas])
#         return f"Challenges activos: {[challenge.id_challenge for challenge in self.challenges_activos]}\nParticipantes:\n{participantes}"

# class Challenge:
#     siguiente_id = 0

#     def __init__(self):
#         Challenge.siguiente_id += 1
#         self.id_challenge = Challenge.siguiente_id
#         self.participantes = []
#         self.estado_objetivo = "En progreso"
#         self.tipo_de_challenge = "Piloto"

#     def agregar_participante(self, participante):
#         if isinstance(participante, Persona):
#             self.participantes.append(participante)
#             participante.challenge = self  # establecer el atributo challenge en la persona correspondiente
#         else:
#             raise ValueError("Solo se pueden agregar objetos de la clase Persona como participantes.")
            
#         if len(self.participantes) == 15:
#             ong.mover_challenge_exitoso(self)

#     def __str__(self):
#         return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nEstado objetivo: {self.estado_objetivo}"


# class Donacion(Challenge):
    
#     def __init__(self):
#         super().__init__()
#         self.tipo_de_challenge = "Donacion"
#         self.monto = 0
#         self.monto_objetivo = 15000
#         self.max_participantes = 30
    
#     def agregar_participante(self, participante):
#         if len(self.participantes) < 30:
#             super().agregar_participante(participante)
#             self.monto += random.randint(10, 900)
#         if self.monto >= self.monto_objetivo:    
#             ong.mover_challenge_exitoso(self)
#         if (len(self.participantes) == self.max_participantes) & (self.monto < self.monto_objetivo):
#             ong.mover_challenge_discontinuado(self)
            
#     def __str__(self):
#         return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nMonto recaudado: {self.monto}\nMonto objetivo: {self.monto_objetivo}\nMáximo de participantes: {self.max_participantes}\nEstado objetivo: {self.estado_objetivo}"        
            
    
# class VoluntariadoTraductor(Challenge):
    
#     def __init__(self):
#         super().__init__()
#         self.tipo_de_challenge = "Traductor"
    
#     def agregar_participante(self, participante):
#         if len(self.participantes) < 12:
#             super().agregar_participante(participante)
#         else:
#             ong.mover_challenge_exitoso(self)
    
#     def __str__(self):
#         return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nEstado objetivo: {self.estado_objetivo}"        

# class VoluntariadoAbogado(Challenge):
    
#     def __init__(self):
#         super().__init__()
#         self.tipo_de_challenge = "Abogado"
    
#     def agregar_participante(self, participante):
#         if len(self.participantes) < 6:
#             super().agregar_participante(participante)
#         else:
#             ong.mover_challenge_exitoso(self)
    
#     def __str__(self):
#         return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nEstado objetivo: {self.estado_objetivo}"        
    

# class VoluntariadoPresencial(Challenge):
    
#     def __init__(self):
#         super().__init__()
#         self.tipo_de_challenge = "Presencial"
    
#     def agregar_participante(self, participante):
#         if len(self.participantes) < 35:
#             super().agregar_participante(participante)
#         else:
#             ong.mover_challenge_exitoso(self)
    
#     def __str__(self):
#         return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nEstado objetivo: {self.estado_objetivo}"        
    

# class Persona:
#     def __init__(self):
#         self.nombre = fake.first_name()
#         self.apellido = fake.last_name()
#         self.nacionalidad = fake.country()
#         self.challenge = None  # atributo para indicar el challenge al que se unió

#     def __str__(self):
#         return f"{self.nombre} {self.apellido}\nNacionalidad: {self.nacionalidad}"

# class CreadorDeChallenge(Persona):
#     def __init__(self, ong):
#         super().__init__()
#         self.challenge_creado = ong.crear_challenge()
#         self.challenge_creado.agregar_participante(self)
#         ong.agregar_persona(self)
        
#     def crear_challenge(self):
#         if random.random() < 0.5:
#             challenge = VoluntariadoPresencial()
#         else:
#             challenge = Challenge()
#         self.challenges_activos.append(challenge)
#         return challenge    
        
#     def nombre_apellido(self):
#         return f"{self.nombre} {self.apellido}"    

#     def __str__(self):
#         return f"Nombre: {self.challenge_creado}\nApellido: {self.apellido}\nNacionalidad: {self.nacionalidad}"    

# class Seguidor(Persona):
#     def __init__(self):
#         super().__init__()
#         self.challenges = []

#     def unirse_challenge(self, challenge):
#         if challenge in self.challenges:
#             print("Ya te uniste a este challenge.")
#         else:
#             challenge.agregar_participante(self)
#             self.challenges.append(challenge)

#     def nombre_apellido(self):
#         return f"{self.nombre} {self.apellido}"

#     def buscar_challenges(self, lista_challenges):
#         for challenge in lista_challenges:
#             print(f"Challenge {challenge.numero}: {len(challenge.participantes)} participantes.")

#     def unirse_challenge_aleatorio(self, ong):
#         challenges = ong.challenges_activos
#         n_challenges = len(challenges)
#         if n_challenges == 0:
#             print("No hay challenges disponibles.")
#             return
#         idx = random.randint(0, n_challenges-1)
#         challenge = challenges[idx]
#         self.unirse_challenge(challenge)

# %%
fake = Faker()

class ONG:
    def __init__(self):
        self.challenges_activos = []
        self.personas = []
        self.challenges_exitosos = []
        self.challenges_discontinuados = []

    def crear_challenge(self):
        rand = random.random()
        if rand < 0.65:
             challenge = Donacion()
        elif rand < 0.85:
             challenge = VoluntariadoPresencial()
        elif rand < 0.94:
             challenge = VoluntariadoTraductor()    
        elif rand < 0.98:
             challenge = VoluntariadoAbogado()
        else:
             challenge = Challenge()
        self.challenges_activos.append(challenge)
        return challenge


    def agregar_persona(self, persona):
         self.personas.append(persona)

    def remover_challenge(self, challenge):
        if challenge in self.challenges_activos:
            self.challenges_activos.remove(challenge)
        else:
            print("El challenge ya no está en la lista.")

    def remover_persona(self, persona):
        if persona in self.personas:
            self.personas.remove(persona)
        else:
            print("La persona ya no está en la lista.")

    def mover_challenge_exitoso(self, challenge):
        if challenge in self.challenges_activos:
            self.challenges_activos.remove(challenge)
            self.challenges_exitosos.append(challenge)
        else:
            print("El challenge no está activo.")

    def mover_challenge_discontinuado(self, challenge):
        if challenge in self.challenges_activos:
            self.challenges_activos.remove(challenge)
            self.challenges_discontinuados.append(challenge)
        else:
            print("El challenge no está activo.")
            
    def discontinuar_todos(self):
        for challenge in self.challenges_activos:
            self.mover_challenge_discontinuado(challenge)
        self.challenges_activos = []

    def __str__(self):
        participantes = "\n".join([f"{p.nombre} {p.apellido}" for p in self.personas])
        return f"Challenges activos: {[challenge.id_challenge for challenge in self.challenges_activos]}\nParticipantes:\n{participantes}"

class Challenge:
    siguiente_id = 0
# CHACHACHA
    def __init__(self):
        Challenge.siguiente_id += 1
        self.id_challenge = "Dic-2022-" + str(Challenge.siguiente_id)
        self.participantes = []
        self.estado_objetivo = "En progreso"
        self.tipo_de_challenge = "Piloto"

    def agregar_participante(self, participante):
        if isinstance(participante, Persona):
            self.participantes.append(participante)
            participante.challenge = self  # establecer el atributo challenge en la persona correspondiente
        else:
            raise ValueError("Solo se pueden agregar objetos de la clase Persona como participantes.")
            
        if len(self.participantes) == 15:
            ong.mover_challenge_exitoso(self)

    def __str__(self):
        return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nEstado objetivo: {self.estado_objetivo}"


class Donacion(Challenge):
    
    def __init__(self):
        super().__init__()
        self.tipo_de_challenge = "Donacion"
        self.monto = 0
        self.monto_objetivo = 15000
        self.max_participantes = 30
    
    def agregar_participante(self, participante):
        if len(self.participantes) < 30:
            super().agregar_participante(participante)
            self.monto += random.randint(10, 900)
        if self.monto >= self.monto_objetivo:    
            ong.mover_challenge_exitoso(self)
        if (len(self.participantes) == self.max_participantes) & (self.monto < self.monto_objetivo):
            ong.mover_challenge_discontinuado(self)
            
    def __str__(self):
        return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nMonto recaudado: {self.monto}\nMonto objetivo: {self.monto_objetivo}\nMáximo de participantes: {self.max_participantes}\nEstado objetivo: {self.estado_objetivo}"        
            
    
class VoluntariadoTraductor(Challenge):
    
    def __init__(self):
        super().__init__()
        self.tipo_de_challenge = "Traductor"
    
    def agregar_participante(self, participante):
        if len(self.participantes) < 12:
            super().agregar_participante(participante)
        else:
            ong.mover_challenge_exitoso(self)
    
    def __str__(self):
        return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nEstado objetivo: {self.estado_objetivo}"        

class VoluntariadoAbogado(Challenge):
    
    def __init__(self):
        super().__init__()
        self.tipo_de_challenge = "Abogado"
    
    def agregar_participante(self, participante):
        if len(self.participantes) < 6:
            super().agregar_participante(participante)
        else:
            ong.mover_challenge_exitoso(self)
    
    def __str__(self):
        return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nEstado objetivo: {self.estado_objetivo}"        
    

class VoluntariadoPresencial(Challenge):
    
    def __init__(self):
        super().__init__()
        self.tipo_de_challenge = "Presencial"
    
    def agregar_participante(self, participante):
        if len(self.participantes) < 35:
            super().agregar_participante(participante)
        else:
            ong.mover_challenge_exitoso(self)
    
    def __str__(self):
        return f"Id challenge: {self.id_challenge}\nTipo de challenge: {self.tipo_de_challenge}\nParticipantes {[participante.nombre_apellido() for participante in self.participantes]}\nEstado objetivo: {self.estado_objetivo}"        
    

class Persona:
    def __init__(self):
        fake = Faker()
        self.nombre = fake.first_name()
        self.apellido = fake.last_name()
        self.edad = self.generar_edad()
        self.mail = fake.email()
        id_num = fake.random_number(digits=8)
        id_letra = chr(fake.random_int(min=65, max=90))
        self.id_nacional = id_letra + str(id_num).zfill(8)
        self.nacionalidad = fake.country()
        self.challenge = None
        self.tipo_challenge = "Ninguno"
        
    def generar_edad(self):
        rand = random.random()
        if rand < 0.55:
            return random.randint(18, 40)
        elif rand < 0.85:
            return random.randint(41, 60)
        elif rand < 0.95:
            return random.randint(61, 70)
        else:
            return random.randint(71, 92)
        
    def __str__(self):
        return f"Nombre: {self.nombre} {self.apellido}\nEdad: {self.edad}\nE-mail: {self.mail}\nID Nacional:\
        {self.id_nacional}\nNacionalidad: {self.nacionalidad}\nTipo de Challenge: {self.tipo_challenge}"
    
    
    
class CreadorDeChallenge(Persona):
    def __init__(self, ong):
        super().__init__()
        self.challenge_creado = ong.crear_challenge()
        self.challenge_creado.agregar_participante(self)
        ong.agregar_persona(self)
        
    def crear_challenge(self):
        if random.random() < 0.5:
            challenge = VoluntariadoPresencial()
        else:
            challenge = Challenge()
        self.challenges_activos.append(challenge)
        return challenge    
        
    def nombre_apellido(self):
        return f"{self.nombre} {self.apellido}"    

    def __str__(self):
        return f"Nombre: {self.nombre} {self.apellido}\nEdad: {self.edad}\nE-mail: {self.mail}\nID Nacional:\
        {self.id_nacional}\nNacionalidad: {self.nacionalidad}\nTipo de Challenge: {self.challenge_creado.tipo_de_challenge}"    

   

class Seguidor(Persona):
    def __init__(self):
        super().__init__()
        self.challenges = []
        self.tipo_challenge = None
        
    def unirse_challenge(self, challenge):
        if challenge in self.challenges:
            print("Ya te uniste a este challenge.")
        else:
            challenge.agregar_participante(self)
            self.challenges.append(challenge)
            self.tipo_challenge = challenge.tipo_de_challenge

    def nombre_apellido(self):
        return f"{self.nombre} {self.apellido}"

    def buscar_challenges(self, lista_challenges):
        for challenge in lista_challenges:
            print(f"Challenge {challenge.numero}: {len(challenge.participantes)} participantes.")

    def unirse_challenge_aleatorio(self, ong):
        challenges = ong.challenges_activos
        n_challenges = len(challenges)
        if n_challenges == 0:
            print("No hay challenges disponibles.")
            return
        idx = random.randint(0, n_challenges-1)
        challenge = challenges[idx]
        self.unirse_challenge(challenge)
    
    
    def __str__(self):
        return f"Nombre: {self.nombre} {self.apellido}\nEdad: {self.edad}\nE-mail: {self.mail}\nID Nacional:\
        {self.id_nacional}\nNacionalidad: {self.nacionalidad}\nTipo de Challenge: {self.tipo_challenge}"

# %%
p = Persona()

# %%
print(p)
# Out:
# Nombre: Cynthia Jackson
# Edad: 65
# E-mail: manueltaylor@example.net
# ID Nacional:        J48224209
# Nacionalidad: Seychelles
# Tipo de Challenge: Ninguno

# %%
p.id_nacional
# Out:
# 'J48224209'

# %%
ong = ONG()

# %%
for i in range(0,6):
    ong.crear_challenge()

# %%
print(ong)
# Out:
# Challenges activos: ['Dic-2022-1', 'Dic-2022-2', 'Dic-2022-3', 'Dic-2022-4', 'Dic-2022-5', 'Dic-2022-6']
# Participantes:

# %%
for challenge in ong.challenges_activos:
    print(challenge.id_challenge)
    print(challenge.tipo_de_challenge)
# Out:
# Dic-2022-1
# Donacion
# Dic-2022-2
# Presencial
# Dic-2022-3
# Donacion
# Dic-2022-4
# Donacion
# Dic-2022-5
# Presencial
# Dic-2022-6
# Donacion

# %%
print(challenge1)
# Out:
# Id challenge: Enero-20221
# Tipo de challenge: Donacion
# Participantes ['Hannah Peterson', 'Danielle Herrera', 'Erica Burton', 'Marcus Davis', 'Katherine Hernandez', 'Katrina Martinez', 'Megan Hall', 'Christopher Mullins', 'Joseph Hernandez', 'Richard Simon', 'Gregory Moore', 'Michelle Simmons', 'Dustin Wright', 'William Winters', 'Elizabeth Warren']
# Monto recaudado: 7295
# Monto objetivo: 15000
# Máximo de participantes: 30
# Estado objetivo: En progreso

# %%
ch = Challenge()

# %%
ch.siguiente_id
# Out:
# 7

# %%
ch.siguiente_id
# Out:
# 7

# %%
#c = CreadorDeChallenge(ong)

# %%
print(ong.challenges_activos[1])
# Out:
# Id challenge: Dic-2022-2
# Tipo de challenge: Presencial
# Participantes []
# Estado objetivo: En progreso

# %%
s = Seguidor()

# %%
#print(s)

# %%
s.unirse_challenge_aleatorio(ong)

# %%
s.tipo_challenge
# Out:
# 'Donacion'

# %%
print(s.challenge.tipo_de_challenge)
# Out:
# Donacion

# %%
print(s.challenge.id_challenge) # Acceder al id de challenge al que se unió una persona
# Out:
# Dic-2022-4

# %%
instancias = []
for i in range(185):
    rand = random.random()
    if rand < 0.46:
        p = Persona()
        print(p)
        print('*'*100)
        instancias.append(p)
    elif rand < 0.56:
        c = CreadorDeChallenge(ong)
        print(c)
        print('*'*100)
        print('*'*100)
        print('*'*100)
        instancias.append(c)
    else:
        s = Seguidor()
        s.unirse_challenge_aleatorio(ong)
        print(s)
        print('*'*100)
        instancias.append(s)
# Out:
# Nombre: Ann Reed
# Edad: 30
# E-mail: jcrane@example.com
# ID Nacional:        O39861382
# Nacionalidad: Niue
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Daniel Brown
# Edad: 45
# E-mail: maureen40@example.net
# ID Nacional:        D88256727
# Nacionalidad: Malta
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Jenna Williams
# Edad: 31
# E-mail: jonathan43@example.com
# ID Nacional:        C20496614
# Nacionalidad: Mauritania
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Elizabeth Nielsen
# Edad: 24
# E-mail: jesus58@example.com
# ID Nacional:        E74827935
# Nacionalidad: Dominica
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Karen Oneill
# Edad: 23
# E-mail: ananewman@example.com
# ID Nacional:        C28284421
# Nacionalidad: Burundi
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Angela Garcia
# Edad: 45
# E-mail: linda10@example.org
# ID Nacional:        C05559705
# Nacionalidad: Cape Verde
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Brandy Walker
# Edad: 31
# E-mail: pward@example.net
# ID Nacional:        F76603206
# Nacionalidad: Gabon
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Gary Dennis
# Edad: 39
# E-mail: kimberlybenitez@example.com
# ID Nacional:        T29427670
# Nacionalidad: Falkland Islands (Malvinas)
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Dale Underwood
# Edad: 26
# E-mail: kevinbell@example.org
# ID Nacional:        T79916914
# Nacionalidad: Equatorial Guinea
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Bethany Reed
# Edad: 35
# E-mail: spowers@example.com
# ID Nacional:        P74625976
# Nacionalidad: Iceland
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Richard Kennedy
# Edad: 28
# E-mail: nicholas67@example.com
# ID Nacional:        C22225093
# Nacionalidad: Lao People's Democratic Republic
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Sandra Clark
# Edad: 64
# E-mail: cardenasmichael@example.com
# ID Nacional:        I21829008
# Nacionalidad: Burkina Faso
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Heidi Burgess
# Edad: 29
# E-mail: daniellerodriguez@example.org
# ID Nacional:        M23027381
# Nacionalidad: Latvia
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Sharon Rojas
# Edad: 33
# E-mail: wadams@example.net
# ID Nacional:        J82780264
# Nacionalidad: Cook Islands
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Nicole Cox
# Edad: 19
# E-mail: qcoleman@example.net
# ID Nacional:        N48206245
# Nacionalidad: Monaco
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Rebecca Miller
# Edad: 72
# E-mail: carrollmichelle@example.net
# ID Nacional:        H95211854
# Nacionalidad: Tanzania
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Christopher Gordon
# Edad: 19
# E-mail: john70@example.org
# ID Nacional:        S01481115
# Nacionalidad: Malawi
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Sabrina Tran
# Edad: 64
# E-mail: serranolori@example.org
# ID Nacional:        R18531709
# Nacionalidad: France
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Joshua Nelson
# Edad: 61
# E-mail: victoriasmith@example.com
# ID Nacional:        O55065290
# Nacionalidad: Bahrain
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Kiara Watkins
# Edad: 41
# E-mail: oraymond@example.com
# ID Nacional:        S75874221
# Nacionalidad: Burundi
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Crystal Santana
# Edad: 69
# E-mail: dianagray@example.org
# ID Nacional:        S55563264
# Nacionalidad: Equatorial Guinea
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Robert Dyer
# Edad: 59
# E-mail: amyspencer@example.net
# ID Nacional:        O71398996
# Nacionalidad: Portugal
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Erica Wright
# Edad: 56
# E-mail: zmiller@example.com
# ID Nacional:        A97295107
# Nacionalidad: Philippines
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Cassandra Joseph
# Edad: 42
# E-mail: jack45@example.net
# ID Nacional:        K85919836
# Nacionalidad: Guernsey
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Erik Davis
# Edad: 53
# E-mail: amyers@example.net
# ID Nacional:        X33403106
# Nacionalidad: India
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Ricky Smith
# Edad: 22
# E-mail: powellanna@example.org
# ID Nacional:        Y62158055
# Nacionalidad: Vanuatu
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Bryan Robinson
# Edad: 60
# E-mail: odomstephanie@example.com
# ID Nacional:        V68090215
# Nacionalidad: Palau
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Garrett Ramsey
# Edad: 33
# E-mail: suzannesanford@example.org
# ID Nacional:        H26515915
# Nacionalidad: Albania
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Maria Lee
# Edad: 45
# E-mail: elizabethstevens@example.org
# ID Nacional:        U89033409
# Nacionalidad: Belgium
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Michael Hill
# Edad: 27
# E-mail: brandykelly@example.org
# ID Nacional:        Q66510692
# Nacionalidad: Chad
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Madison Warren
# Edad: 39
# E-mail: williambonilla@example.org
# ID Nacional:        U89099578
# Nacionalidad: Puerto Rico
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Justin Clark
# Edad: 18
# E-mail: jordantroy@example.com
# ID Nacional:        O15443553
# Nacionalidad: Central African Republic
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Matthew Ewing
# Edad: 38
# E-mail: andrew92@example.net
# ID Nacional:        O19198831
# Nacionalidad: Ecuador
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: David Hayes
# Edad: 39
# E-mail: martinezjerry@example.net
# ID Nacional:        N48975470
# Nacionalidad: Zimbabwe
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Robert Sawyer
# Edad: 37
# E-mail: tmiller@example.net
# ID Nacional:        K66581709
# Nacionalidad: Czech Republic
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Gary Brewer
# Edad: 87
# E-mail: bakerzachary@example.org
# ID Nacional:        I45697333
# Nacionalidad: Gambia
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Katherine Crawford
# Edad: 75
# E-mail: bennettmia@example.net
# ID Nacional:        S42203422
# Nacionalidad: Greenland
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Timothy Elliott
# Edad: 37
# E-mail: chelseadiaz@example.net
# ID Nacional:        G07938103
# Nacionalidad: France
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Erica Berry
# Edad: 51
# E-mail: devinbradley@example.net
# ID Nacional:        R96795567
# Nacionalidad: Honduras
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Kathryn Clark
# Edad: 30
# E-mail: monica25@example.net
# ID Nacional:        Z83349588
# Nacionalidad: Palestinian Territory
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Rebecca Gonzalez
# Edad: 31
# E-mail: hansonlawrence@example.net
# ID Nacional:        D82120097
# Nacionalidad: Fiji
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Susan Taylor
# Edad: 66
# E-mail: hornemichael@example.org
# ID Nacional:        Y05944444
# Nacionalidad: Djibouti
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Deborah Medina
# Edad: 42
# E-mail: carl17@example.com
# ID Nacional:        K11860101
# Nacionalidad: Wallis and Futuna
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Phillip Campbell
# Edad: 68
# E-mail: brownchristopher@example.com
# ID Nacional:        O34384193
# Nacionalidad: Ukraine
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Sharon Johnson
# Edad: 39
# E-mail: rachel80@example.net
# ID Nacional:        C82730605
# Nacionalidad: Kuwait
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Deborah Drake
# Edad: 69
# E-mail: qcooper@example.net
# ID Nacional:        V01410163
# Nacionalidad: Austria
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Stephanie Leach
# Edad: 88
# E-mail: hturner@example.net
# ID Nacional:        U57353030
# Nacionalidad: Eritrea
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Christopher Williams
# Edad: 27
# E-mail: jacob20@example.com
# ID Nacional:        X86192951
# Nacionalidad: Gambia
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Sherri Baker
# Edad: 56
# E-mail: dennismelissa@example.org
# ID Nacional:        V93847706
# Nacionalidad: Martinique
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Paul Collins
# Edad: 20
# E-mail: jonathan78@example.net
# ID Nacional:        T41386859
# Nacionalidad: Kuwait
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Edwin Pineda
# Edad: 21
# E-mail: blairnathan@example.com
# ID Nacional:        B76664727
# Nacionalidad: Martinique
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Jessica Becker
# Edad: 51
# E-mail: brettbarber@example.org
# ID Nacional:        V55600910
# Nacionalidad: Isle of Man
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Cindy Morgan
# Edad: 30
# E-mail: umartinez@example.net
# ID Nacional:        R79153463
# Nacionalidad: Uzbekistan
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Micheal Reed
# Edad: 49
# E-mail: gomezmark@example.com
# ID Nacional:        R39644481
# Nacionalidad: Saudi Arabia
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Christopher Brown
# Edad: 19
# E-mail: kjuarez@example.com
# ID Nacional:        J53747758
# Nacionalidad: Saint Pierre and Miquelon
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Austin Stone
# Edad: 36
# E-mail: hlove@example.com
# ID Nacional:        S81106805
# Nacionalidad: Algeria
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Erik Lewis
# Edad: 30
# E-mail: gbrown@example.org
# ID Nacional:        O33846255
# Nacionalidad: New Zealand
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Tina Anderson
# Edad: 45
# E-mail: moorestacey@example.com
# ID Nacional:        O24839371
# Nacionalidad: Niger
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Maria Eaton
# Edad: 55
# E-mail: leslie62@example.net
# ID Nacional:        F26858174
# Nacionalidad: Iceland
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Erin James
# Edad: 65
# E-mail: cblankenship@example.org
# ID Nacional:        G15234103
# Nacionalidad: Netherlands
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Heather Perkins
# Edad: 48
# E-mail: kentbailey@example.com
# ID Nacional:        J67098558
# Nacionalidad: Solomon Islands
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Anthony Atkins
# Edad: 38
# E-mail: barrjulie@example.org
# ID Nacional:        O99580620
# Nacionalidad: American Samoa
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Alexa Ward
# Edad: 36
# E-mail: susan87@example.net
# ID Nacional:        F34922389
# Nacionalidad: Cote d'Ivoire
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Austin Sims
# Edad: 38
# E-mail: angelaschaefer@example.net
# ID Nacional:        B26718350
# Nacionalidad: Jersey
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Christopher Larsen
# Edad: 51
# E-mail: briancross@example.net
# ID Nacional:        Z76849792
# Nacionalidad: Cayman Islands
# Tipo de Challenge: Traductor
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Brandi Gutierrez
# Edad: 27
# E-mail: jamierose@example.org
# ID Nacional:        P28911905
# Nacionalidad: Trinidad and Tobago
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Joseph Wong
# Edad: 42
# E-mail: debbie32@example.org
# ID Nacional:        A28915900
# Nacionalidad: Nepal
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Donald Nguyen
# Edad: 53
# E-mail: isutton@example.org
# ID Nacional:        U19977069
# Nacionalidad: Slovenia
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Jennifer Cameron
# Edad: 54
# E-mail: shepherdtravis@example.net
# ID Nacional:        P84155814
# Nacionalidad: Ethiopia
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Teresa Mckenzie
# Edad: 24
# E-mail: jessehamilton@example.com
# ID Nacional:        U83314517
# Nacionalidad: Sweden
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Desiree Weiss
# Edad: 44
# E-mail: ijohnson@example.com
# ID Nacional:        I21814606
# Nacionalidad: Christmas Island
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Kelly Sharp
# Edad: 38
# E-mail: teresaflores@example.com
# ID Nacional:        O91537537
# Nacionalidad: Sierra Leone
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Heidi Stokes
# Edad: 54
# E-mail: andrew50@example.net
# ID Nacional:        P07156397
# Nacionalidad: Mauritius
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Deanna Burke
# Edad: 19
# E-mail: nicolelutz@example.org
# ID Nacional:        L38681233
# Nacionalidad: Thailand
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Kerry Baird
# Edad: 56
# E-mail: gomezluke@example.net
# ID Nacional:        K83559163
# Nacionalidad: Portugal
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Andrew Rodriguez
# Edad: 31
# E-mail: david05@example.com
# ID Nacional:        R48281856
# Nacionalidad: Antigua and Barbuda
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Parker Kelley
# Edad: 53
# E-mail: nancy16@example.com
# ID Nacional:        Y93490820
# Nacionalidad: Antarctica (the territory South of 60 deg S)
# Tipo de Challenge: Traductor
# ****************************************************************************************************
# Nombre: James Lee
# Edad: 38
# E-mail: joshua63@example.org
# ID Nacional:        Q04309299
# Nacionalidad: Colombia
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Robert Gomez
# Edad: 28
# E-mail: ashleejordan@example.com
# ID Nacional:        R00802890
# Nacionalidad: Tunisia
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Tracy Shea
# Edad: 19
# E-mail: katie56@example.com
# ID Nacional:        G70103926
# Nacionalidad: Aruba
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Tiffany Watson
# Edad: 63
# E-mail: andrew55@example.net
# ID Nacional:        H90016767
# Nacionalidad: Niue
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Nicole Contreras
# Edad: 69
# E-mail: laura18@example.com
# ID Nacional:        L91568533
# Nacionalidad: Saint Kitts and Nevis
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Richard Cain
# Edad: 36
# E-mail: kristen11@example.com
# ID Nacional:        V53240172
# Nacionalidad: Peru
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Heather Henderson
# Edad: 36
# E-mail: amanda58@example.net
# ID Nacional:        I60959851
# Nacionalidad: Finland
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Scott Burns
# Edad: 37
# E-mail: murrayjessica@example.org
# ID Nacional:        S71650081
# Nacionalidad: Dominican Republic
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Megan Spencer
# Edad: 38
# E-mail: zortiz@example.com
# ID Nacional:        V15194497
# Nacionalidad: Angola
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: James Sullivan
# Edad: 32
# E-mail: marshlori@example.org
# ID Nacional:        H00316473
# Nacionalidad: Serbia
# Tipo de Challenge: Traductor
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Douglas Medina
# Edad: 38
# E-mail: asalazar@example.net
# ID Nacional:        F81823145
# Nacionalidad: Philippines
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Kelly Martinez
# Edad: 49
# E-mail: xmartin@example.org
# ID Nacional:        C37695847
# Nacionalidad: Oman
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Steve Miller
# Edad: 66
# E-mail: jessica49@example.net
# ID Nacional:        M47250914
# Nacionalidad: Mauritius
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Garrett Jensen
# Edad: 69
# E-mail: amanda01@example.com
# ID Nacional:        A02510809
# Nacionalidad: Saint Pierre and Miquelon
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Jessica Perez
# Edad: 56
# E-mail: karenhunter@example.net
# ID Nacional:        L89526949
# Nacionalidad: Russian Federation
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Sarah Baker
# Edad: 53
# E-mail: pgross@example.net
# ID Nacional:        D29222064
# Nacionalidad: Tanzania
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Andre Morales
# Edad: 40
# E-mail: vanessaortiz@example.com
# ID Nacional:        A57971369
# Nacionalidad: Benin
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Nancy Deleon
# Edad: 27
# E-mail: josenunez@example.net
# ID Nacional:        N35571926
# Nacionalidad: Cocos (Keeling) Islands
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Judy Knight
# Edad: 60
# E-mail: ynielsen@example.com
# ID Nacional:        H87495398
# Nacionalidad: Netherlands
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Darrell Collins
# Edad: 40
# E-mail: ralph51@example.org
# ID Nacional:        I74694164
# Nacionalidad: Cocos (Keeling) Islands
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Bradley Campbell
# Edad: 52
# E-mail: cole53@example.com
# ID Nacional:        K54293305
# Nacionalidad: Aruba
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Samuel Cross
# Edad: 59
# E-mail: johnsonbeth@example.net
# ID Nacional:        F69944220
# Nacionalidad: Panama
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Vincent Cunningham
# Edad: 56
# E-mail: kayla98@example.org
# ID Nacional:        C80242003
# Nacionalidad: United States Minor Outlying Islands
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Rebecca Walker
# Edad: 46
# E-mail: melissa29@example.com
# ID Nacional:        I56603842
# Nacionalidad: Bahamas
# Tipo de Challenge: Abogado
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Jacob Martin
# Edad: 47
# E-mail: robert06@example.com
# ID Nacional:        T08003937
# Nacionalidad: Bahrain
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Sara Richards
# Edad: 26
# E-mail: chase63@example.net
# ID Nacional:        X20688552
# Nacionalidad: Gabon
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: George Hernandez
# Edad: 33
# E-mail: martinkeith@example.com
# ID Nacional:        M83483172
# Nacionalidad: French Southern Territories
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Amy Ward
# Edad: 21
# E-mail: jessicatate@example.net
# ID Nacional:        F23647842
# Nacionalidad: Antarctica (the territory South of 60 deg S)
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Misty Williams
# Edad: 40
# E-mail: grantkimberly@example.net
# ID Nacional:        X63076626
# Nacionalidad: Brazil
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Nathan Young
# Edad: 66
# E-mail: changcharles@example.org
# ID Nacional:        A93962603
# Nacionalidad: Niger
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Paul Elliott
# Edad: 20
# E-mail: torreschristina@example.net
# ID Nacional:        Q49935093
# Nacionalidad: Jordan
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Patrick Wilson
# Edad: 34
# E-mail: joann62@example.com
# ID Nacional:        Z12874199
# Nacionalidad: Kiribati
# Tipo de Challenge: Abogado
# ****************************************************************************************************
# Nombre: Alice Jones
# Edad: 47
# E-mail: petersenscott@example.net
# ID Nacional:        L66119717
# Nacionalidad: Romania
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Brendan Martinez
# Edad: 38
# E-mail: twallace@example.net
# ID Nacional:        L07431300
# Nacionalidad: Belize
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Travis Brown
# Edad: 23
# E-mail: fcummings@example.org
# ID Nacional:        Q71976795
# Nacionalidad: Belize
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Vicki Gibson
# Edad: 52
# E-mail: lopezjohn@example.org
# ID Nacional:        K50519155
# Nacionalidad: Ethiopia
# Tipo de Challenge: Abogado
# ****************************************************************************************************
# Nombre: Mckenzie Chambers
# Edad: 51
# E-mail: kennedyjeffrey@example.com
# ID Nacional:        T94432707
# Nacionalidad: Niue
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Nancy Rodriguez
# Edad: 28
# E-mail: rlopez@example.com
# ID Nacional:        F66125143
# Nacionalidad: Antarctica (the territory South of 60 deg S)
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Michael Morgan
# Edad: 38
# E-mail: crystal05@example.org
# ID Nacional:        W65114268
# Nacionalidad: Georgia
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Maria Walters
# Edad: 28
# E-mail: jerry18@example.net
# ID Nacional:        C53912698
# Nacionalidad: British Indian Ocean Territory (Chagos Archipelago)
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Cynthia Porter
# Edad: 56
# E-mail: keithduffy@example.org
# ID Nacional:        J55962671
# Nacionalidad: Lesotho
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Diane Wood
# Edad: 40
# E-mail: smithrichard@example.net
# ID Nacional:        W83349439
# Nacionalidad: Tuvalu
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Maria Johnson
# Edad: 64
# E-mail: leesamuel@example.com
# ID Nacional:        U27644396
# Nacionalidad: Cayman Islands
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Kaitlyn Moore
# Edad: 61
# E-mail: carolinevargas@example.com
# ID Nacional:        F76959241
# Nacionalidad: Kuwait
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Jimmy Sparks
# Edad: 27
# E-mail: nelsonrebecca@example.com
# ID Nacional:        K65336221
# Nacionalidad: Saudi Arabia
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Allison Scott
# Edad: 50
# E-mail: frank75@example.com
# ID Nacional:        F33224218
# Nacionalidad: United States Minor Outlying Islands
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Robin Dorsey
# Edad: 24
# E-mail: sarah98@example.com
# ID Nacional:        T23753838
# Nacionalidad: Nepal
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Yolanda Steele
# Edad: 24
# E-mail: lance36@example.net
# ID Nacional:        K73205087
# Nacionalidad: Sweden
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Jessica Williams
# Edad: 57
# E-mail: raycraig@example.net
# ID Nacional:        O74071631
# Nacionalidad: Kiribati
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Stacy Tapia
# Edad: 78
# E-mail: ounderwood@example.org
# ID Nacional:        W70119857
# Nacionalidad: Switzerland
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Robert Dunn
# Edad: 37
# E-mail: cisnerostracy@example.org
# ID Nacional:        S43780396
# Nacionalidad: Georgia
# Tipo de Challenge: Abogado
# ****************************************************************************************************
# Nombre: Michael Guerra
# Edad: 37
# E-mail: devinguerra@example.org
# ID Nacional:        S23542120
# Nacionalidad: Kyrgyz Republic
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Marissa Rosario
# Edad: 60
# E-mail: victoria22@example.net
# ID Nacional:        L06593220
# Nacionalidad: Philippines
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Erika Smith
# Edad: 84
# E-mail: katherine81@example.net
# ID Nacional:        S27770042
# Nacionalidad: Colombia
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Meghan Smith
# Edad: 89
# E-mail: iball@example.net
# ID Nacional:        F98453035
# Nacionalidad: Andorra
# Tipo de Challenge: Abogado
# ****************************************************************************************************
# Nombre: Nathan Cervantes
# Edad: 21
# E-mail: iblair@example.net
# ID Nacional:        C68285986
# Nacionalidad: Denmark
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Bruce Townsend
# Edad: 35
# E-mail: gregory12@example.net
# ID Nacional:        C61294750
# Nacionalidad: Lesotho
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Timothy Cain
# Edad: 37
# E-mail: johnburch@example.net
# ID Nacional:        B51065662
# Nacionalidad: Kazakhstan
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Pamela Miller
# Edad: 58
# E-mail: eric35@example.net
# ID Nacional:        A67006465
# Nacionalidad: Russian Federation
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: John Guerrero
# Edad: 29
# E-mail: cgamble@example.org
# ID Nacional:        H36085981
# Nacionalidad: Finland
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: David Murray
# Edad: 25
# E-mail: javiercoleman@example.org
# ID Nacional:        K43195721
# Nacionalidad: Ukraine
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Caitlin Hawkins
# Edad: 54
# E-mail: zkaiser@example.com
# ID Nacional:        N27657158
# Nacionalidad: Slovenia
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Joel Murphy
# Edad: 53
# E-mail: garciasteven@example.org
# ID Nacional:        B96956621
# Nacionalidad: Macedonia
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Darryl Flores
# Edad: 51
# E-mail: wbaker@example.org
# ID Nacional:        B00239749
# Nacionalidad: Mexico
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Nicholas Jenkins
# Edad: 66
# E-mail: ebruce@example.net
# ID Nacional:        W93310215
# Nacionalidad: Philippines
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Maria Johnson
# Edad: 61
# E-mail: erosario@example.org
# ID Nacional:        M17633930
# Nacionalidad: Canada
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Gary Nichols
# Edad: 37
# E-mail: joysnyder@example.com
# ID Nacional:        B95126313
# Nacionalidad: Senegal
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Danielle Huerta
# Edad: 61
# E-mail: tyleranderson@example.org
# ID Nacional:        M37828608
# Nacionalidad: Vanuatu
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Justin Stephens
# Edad: 35
# E-mail: fpalmer@example.net
# ID Nacional:        L12930928
# Nacionalidad: Serbia
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Tyler Guzman
# Edad: 20
# E-mail: imiller@example.net
# ID Nacional:        H30734268
# Nacionalidad: Suriname
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Jonathan Miller
# Edad: 63
# E-mail: danielkeith@example.org
# ID Nacional:        C21769224
# Nacionalidad: Luxembourg
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Edward Hicks
# Edad: 73
# E-mail: knapppaula@example.org
# ID Nacional:        T84235723
# Nacionalidad: Samoa
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Russell Fernandez
# Edad: 23
# E-mail: leelisa@example.net
# ID Nacional:        Y11026082
# Nacionalidad: Nigeria
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Christopher Phillips
# Edad: 30
# E-mail: ashleygilbert@example.com
# ID Nacional:        G67973011
# Nacionalidad: Andorra
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Erica Edwards
# Edad: 66
# E-mail: ksmith@example.net
# ID Nacional:        S70326055
# Nacionalidad: Cameroon
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Christopher Cole
# Edad: 63
# E-mail: smcguire@example.net
# ID Nacional:        B04050600
# Nacionalidad: French Guiana
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Jose Williams
# Edad: 63
# E-mail: hardinbeth@example.com
# ID Nacional:        N91224434
# Nacionalidad: Qatar
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Joshua Nguyen
# Edad: 35
# E-mail: dennistaylor@example.org
# ID Nacional:        Z59085601
# Nacionalidad: Saint Lucia
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Heather Cameron
# Edad: 28
# E-mail: sara99@example.net
# ID Nacional:        R54605831
# Nacionalidad: Benin
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Ralph Williamson
# Edad: 26
# E-mail: qfarrell@example.org
# ID Nacional:        O57648887
# Nacionalidad: Slovakia (Slovak Republic)
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Gabrielle White
# Edad: 70
# E-mail: allencolleen@example.org
# ID Nacional:        R90974503
# Nacionalidad: Philippines
# Tipo de Challenge: Abogado
# ****************************************************************************************************
# Nombre: Christina Cannon
# Edad: 25
# E-mail: jacquelinewood@example.org
# ID Nacional:        E09000652
# Nacionalidad: Heard Island and McDonald Islands
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Dawn Mendez
# Edad: 41
# E-mail: guymcintyre@example.net
# ID Nacional:        V30130726
# Nacionalidad: Jordan
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Kenneth Bates
# Edad: 61
# E-mail: michaelvasquez@example.net
# ID Nacional:        M71302914
# Nacionalidad: Portugal
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Lauren Parks
# Edad: 19
# E-mail: kelly57@example.com
# ID Nacional:        R00822278
# Nacionalidad: Portugal
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Megan Fisher
# Edad: 34
# E-mail: jeffreyjackson@example.com
# ID Nacional:        O07600646
# Nacionalidad: Kiribati
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Kevin Hines
# Edad: 51
# E-mail: maureen25@example.net
# ID Nacional:        H41564393
# Nacionalidad: Malaysia
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Kenneth West
# Edad: 27
# E-mail: jodydavidson@example.net
# ID Nacional:        Y95747488
# Nacionalidad: Faroe Islands
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Amanda Wagner
# Edad: 71
# E-mail: ihall@example.com
# ID Nacional:        U03871615
# Nacionalidad: Costa Rica
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Leah Green
# Edad: 21
# E-mail: tbrown@example.org
# ID Nacional:        G43786564
# Nacionalidad: Liberia
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Linda Hickman
# Edad: 42
# E-mail: gford@example.com
# ID Nacional:        W67254787
# Nacionalidad: Saint Martin
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Brandi Sanford
# Edad: 25
# E-mail: ujones@example.net
# ID Nacional:        O44195380
# Nacionalidad: Cote d'Ivoire
# Tipo de Challenge: Traductor
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Patrick Hubbard
# Edad: 28
# E-mail: carlos36@example.net
# ID Nacional:        H22559654
# Nacionalidad: Uzbekistan
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Charles Rivera
# Edad: 39
# E-mail: qmartinez@example.com
# ID Nacional:        M75698417
# Nacionalidad: New Caledonia
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Rebecca Williams
# Edad: 52
# E-mail: jacksonwilliam@example.net
# ID Nacional:        I62246074
# Nacionalidad: Central African Republic
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Robert Sanders
# Edad: 20
# E-mail: garybriggs@example.net
# ID Nacional:        B48687017
# Nacionalidad: Korea
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# Nombre: Mary Mcclain
# Edad: 26
# E-mail: zritter@example.com
# ID Nacional:        O68357971
# Nacionalidad: Iceland
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Sheri Armstrong
# Edad: 29
# E-mail: sherry43@example.com
# ID Nacional:        N94443481
# Nacionalidad: Bermuda
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Elijah Keller
# Edad: 43
# E-mail: debra87@example.com
# ID Nacional:        M78324216
# Nacionalidad: Bahamas
# Tipo de Challenge: Donacion
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Melissa Smith
# Edad: 55
# E-mail: hillmichael@example.net
# ID Nacional:        M34972325
# Nacionalidad: Pitcairn Islands
# Tipo de Challenge: Abogado
# ****************************************************************************************************
# Nombre: Pamela Ingram
# Edad: 38
# E-mail: hughestaylor@example.org
# ID Nacional:        Y73595789
# Nacionalidad: Croatia
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Robert Johnson
# Edad: 35
# E-mail: stoutmichael@example.com
# ID Nacional:        Z18239827
# Nacionalidad: Niger
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Ashlee Reynolds
# Edad: 42
# E-mail: johnsonterry@example.net
# ID Nacional:        R39407218
# Nacionalidad: New Zealand
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Ana Cox
# Edad: 32
# E-mail: sweiss@example.net
# ID Nacional:        W92886455
# Nacionalidad: Burkina Faso
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Donald Miller
# Edad: 23
# E-mail: whitekyle@example.net
# ID Nacional:        B69136705
# Nacionalidad: Martinique
# Tipo de Challenge: Ninguno
# ****************************************************************************************************
# Nombre: Tracy Pratt
# Edad: 22
# E-mail: andrewcortez@example.net
# ID Nacional:        P30400129
# Nacionalidad: Israel
# Tipo de Challenge: Presencial
# ****************************************************************************************************
# Nombre: Abigail Martin
# Edad: 68
# E-mail: melissa88@example.com
# ID Nacional:        Z01433573
# Nacionalidad: Guatemala
# Tipo de Challenge: Abogado
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Nombre: Trevor Lane
# Edad: 40
# E-mail: cwilliams@example.org
# ID Nacional:        V22573344
# Nacionalidad: Guinea-Bissau
# Tipo de Challenge: Ninguno
# ****************************************************************************************************

# %%
# for i in range(0,150):
#     rand = random.random()
#     if rand < 0.96:
#         s = Seguidor()
#     else:
#         c = CreadorDeChallenge(ong)

# %%
 for i in range(0,185):
    s = Seguidor()
    s.unirse_challenge_aleatorio(ong)
    instancias.append(s)

# %%
# Escribir los datos de cada instancia en el archivo CSV
with open('instancias2.csv', mode='w', newline='') as archivo:
    writer = csv.writer(archivo)
    writer.writerow(['Nombre', 'Apellido', 'Edad', 'Correo electrónico', 'ID Nacional', 'Nacionalidad', 'Tipo de Challenge', 'Tipo de instancia'])
    for inst in instancias:
        if isinstance(inst, CreadorDeChallenge):
            # Si es una instancia de CreadorDeChallenge, escribir los datos correspondientes
            writer.writerow([inst.nombre, inst.apellido, inst.edad, inst.mail, inst.id_nacional, inst.nacionalidad, inst.tipo_challenge, str(type(inst).__name__)])
        elif isinstance(inst, Seguidor):
            # Si es una instancia de Seguidor, escribir los datos correspondientes
            writer.writerow([inst.nombre, inst.apellido, inst.edad, inst.mail, inst.id_nacional, inst.nacionalidad, inst.tipo_challenge , str(type(inst).__name__)])
        elif isinstance(inst, Persona):
            # Si es una instancia de Persona, escribir los datos correspondientes
            writer.writerow([inst.nombre, inst.apellido, inst.edad, inst.mail, inst.id_nacional, inst.nacionalidad, '', str(type(inst).__name__)])
        else:
            # Si es otra instancia, ignorarla
            pass

# %%
for challenge in ong.challenges_exitosos:
    print(challenge.id_challenge)
    print(challenge.tipo_de_challenge)
# Out:
# Dic-2022-18
# Abogado
# Dic-2022-28
# Abogado
# Dic-2022-5
# Presencial
# Dic-2022-12
# Presencial
# Dic-2022-9
# Donacion
# Dic-2022-1
# Donacion
# Dic-2022-11
# Presencial

# %%
ong.discontinuar_todos()

# %%
for challenge in ong.challenges_discontinuados:
    print(challenge.id_challenge)
    print(challenge.tipo_de_challenge)
# Out:
# Dic-2022-2
# Presencial
# Dic-2022-4
# Donacion
# Dic-2022-8
# Donacion
# Dic-2022-13
# Donacion
# Dic-2022-15
# Donacion
# Dic-2022-17
# Donacion
# Dic-2022-20
# Presencial
# Dic-2022-22
# Donacion
# Dic-2022-24
# Donacion
# Dic-2022-26
# Traductor

# %%
ratio_de_exito = len(ong.challenges_exitosos)/(len(ong.challenges_exitosos) + len(ong.challenges_discontinuados))
ratio_de_exito = round(ratio_de_exito,2)
ratio_de_exito
# Out:
# 0.41

# %%
# Crear una lista vacía para almacenar las tuplas
challenges_exitos = []

# Iterar sobre la lista de objetos
for challenge in ong.challenges_exitosos:
    # Obtener el valor de los atributos y agregarlos a una tupla
    challenge_info = (challenge.id_challenge, challenge.tipo_de_challenge, 'exitoso')
    
    # Agregar la tupla a la lista de información de challenges
    challenges_exitos.append(challenge_info)

# %%
challenges_exitos
# Out:
# [('Dic-2022-18', 'Abogado', 'exitoso'),
#  ('Dic-2022-28', 'Abogado', 'exitoso'),
#  ('Dic-2022-5', 'Presencial', 'exitoso'),
#  ('Dic-2022-12', 'Presencial', 'exitoso'),
#  ('Dic-2022-9', 'Donacion', 'exitoso'),
#  ('Dic-2022-1', 'Donacion', 'exitoso'),
#  ('Dic-2022-11', 'Presencial', 'exitoso')]

# %%
# Crear una lista vacía para almacenar las tuplas
challenges_disc = []

# Iterar sobre la lista de objetos
for challenge in ong.challenges_discontinuados:
    # Obtener el valor de los atributos y agregarlos a una tupla
    challenge_info_disc = (challenge.id_challenge, challenge.tipo_de_challenge, 'discontinuado')    
    # Agregar la tupla a la lista de información de challenges
    challenges_disc.append(challenge_info_disc)
    
challenges_disc
# Out:
# [('Dic-2022-2', 'Presencial', 'discontinuado'),
#  ('Dic-2022-4', 'Donacion', 'discontinuado'),
#  ('Dic-2022-8', 'Donacion', 'discontinuado'),
#  ('Dic-2022-13', 'Donacion', 'discontinuado'),
#  ('Dic-2022-15', 'Donacion', 'discontinuado'),
#  ('Dic-2022-17', 'Donacion', 'discontinuado'),
#  ('Dic-2022-20', 'Presencial', 'discontinuado'),
#  ('Dic-2022-22', 'Donacion', 'discontinuado'),
#  ('Dic-2022-24', 'Donacion', 'discontinuado'),
#  ('Dic-2022-26', 'Traductor', 'discontinuado')]

# %%
# Crear un DataFrame a partir de la lista de tuplas
df_ex = pd.DataFrame(challenges_exitos, columns=['id_challenge', 'tipo_de_challenge', 'resultado'])

# %%
# Crear un DataFrame a partir de la lista de tuplas
df_disc = pd.DataFrame(challenges_disc, columns=['id_challenge', 'tipo_de_challenge', 'resultado'])

# %%
df_disc
# Out:
#   id_challenge tipo_de_challenge      resultado
# 0   Dic-2022-2        Presencial  discontinuado
# 1   Dic-2022-4          Donacion  discontinuado
# 2   Dic-2022-8          Donacion  discontinuado
# 3  Dic-2022-13          Donacion  discontinuado
# 4  Dic-2022-15          Donacion  discontinuado
# 5  Dic-2022-17          Donacion  discontinuado
# 6  Dic-2022-20        Presencial  discontinuado
# 7  Dic-2022-22          Donacion  discontinuado
# 8  Dic-2022-24          Donacion  discontinuado
# 9  Dic-2022-26         Traductor  discontinuado

# %%
df_ex
# Out:
#   id_challenge tipo_de_challenge resultado
# 0  Dic-2022-18           Abogado   exitoso
# 1  Dic-2022-28           Abogado   exitoso
# 2   Dic-2022-5        Presencial   exitoso
# 3  Dic-2022-12        Presencial   exitoso
# 4   Dic-2022-9          Donacion   exitoso
# 5   Dic-2022-1          Donacion   exitoso
# 6  Dic-2022-11        Presencial   exitoso

# %%
df_res_dic = pd.concat([df_ex,df_disc])

# %%
df_res_dic
# Out:
#   id_challenge tipo_de_challenge      resultado
# 0  Dic-2022-18           Abogado        exitoso
# 1  Dic-2022-28           Abogado        exitoso
# 2   Dic-2022-5        Presencial        exitoso
# 3  Dic-2022-12        Presencial        exitoso
# 4   Dic-2022-9          Donacion        exitoso
# 5   Dic-2022-1          Donacion        exitoso
# 6  Dic-2022-11        Presencial        exitoso
# 0   Dic-2022-2        Presencial  discontinuado
# 1   Dic-2022-4          Donacion  discontinuado
# 2   Dic-2022-8          Donacion  discontinuado
# 3  Dic-2022-13          Donacion  discontinuado
# 4  Dic-2022-15          Donacion  discontinuado
# 5  Dic-2022-17          Donacion  discontinuado
# 6  Dic-2022-20        Presencial  discontinuado
# 7  Dic-2022-22          Donacion  discontinuado
# 8  Dic-2022-24          Donacion  discontinuado
# 9  Dic-2022-26         Traductor  discontinuado

# %%
df_res_dic.to_csv('gente\\dic_2022_resultados.csv',index = False)

# %%
import pandas as pd

# %%
df = pd.read_csv('gente\\instancias2.csv', encoding = 'latin')

# %%
df

# %%
df['Tipo de Challenge'].value_counts()

# %%
# class ONG:
#     def __init__(self):
#         self.challenges_activos = []
#         self.personas = []
#         self.challenges_exitosos = []
#         self.challenges_discontinuados = []

#     def crear_challenge(self):
#         rand = random.random()
#         if rand < 0.7:
#             challenge = Donacion()
#         elif rand < 0.87:
#             challenge = VoluntariadoPresencial()
#         elif rand < 0.93:
#             challenge = VoluntariadoTraductor()    
#         elif rand < 0.98:
#             challenge = VoluntariadoAbogado()
#         else:
#             challenge = Challenge()
#         self.challenges_activos.append(challenge)
#         return challenge

#     def agregar_persona(self, persona, ubicacion):
#         persona.ubicacion = ubicacion
#         self.personas.append(persona)

#     def remover_challenge(self, challenge):
#         if challenge in self.challenges_activos:
#             self.challenges_activos.remove(challenge)
#         else:
#             print("El challenge ya no está en la lista.")

#     def remover_persona(self, persona):
#         if persona in self.personas:
#             self.personas.remove(persona)
#         else:
#             print("La persona ya no está en la lista.")

#     def mover_challenge_exitoso(self, challenge):
#         if challenge in self.challenges_activos:
#             self.challenges_activos.remove(challenge)
#             self.challenges_exitosos.append(challenge)
#         else:
#             print("El challenge no está activo.")

#     def mover_challenge_discontinuado(self, challenge):
#         if challenge in self.challenges_activos:
#             self.challenges_activos.remove(challenge)
#             self.challenges_discontinuados.append(challenge)
#         else:
#             print("El challenge no está activo.")
            
#     def discontinuar_todos(self):
#         for challenge in self.challenges_activos:
#             self.mover_challenge_discontinuado(challenge)
#         self.challenges_activos = []

#     def __str__(self):
#         participantes = "\n".join([f"{p.nombre} {p.apellido} ({p.ubicacion})" for p in self.personas])
#         return f"Challenges activos: {[challenge.id_challenge for challenge in self.challenges_activos]}\nParticipantes:\n{participantes}"
