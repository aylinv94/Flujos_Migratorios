# %% [markdown]
# # Pobreza y desigualdad

# %% [markdown]
# - [Plataforma de pobreza y desigualdad del Banco Mundial](https://pip.worldbank.org/home)
# - [Methodology](https://datanalytics.worldbank.org/PIP-Methodology/)
# - [API](https://pip.worldbank.org/poverty-calculator)

# %% [markdown]
# La línea de pobreza de este set de datos se calcula tomando la mediana de la parte superior de los países de mediano ingreso

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# #### Dejamos por fuera las columnas con metadata

# %%
df = pd.read_csv("dataSetsEDA\\pop_in_poverty\\pip2.csv", 
                 usecols= ['region_name', 'country_name','reporting_year', 'poverty_line',
                           'headcount','poverty_gap', 'poverty_severity','watts', 'mld', 'gini','polarization','cpi', 'ppp', 
                            'reporting_pop', 'reporting_gdp'])

# %% [markdown]
# ## Antes que nada vamos a filtrar los años que nos interesan

# %%
df.reporting_year.min()
# Out:
# 1967

# %%
df.reporting_year.max()
# Out:
# 2021

# %%
df = df[df.reporting_year >= 1990 ]
df = df[df.reporting_year < 2021 ]

# %%
df.head()
# Out:
#              region_name country_name  reporting_year  poverty_line  \
# 0     Sub-Saharan Africa       Angola            2000          6.85
# 1     Sub-Saharan Africa       Angola            2008          6.85
# 2     Sub-Saharan Africa       Angola            2018          6.85
# 3  Europe & Central Asia      Albania            1996          6.85
# 4  Europe & Central Asia      Albania            2002          6.85
#
#    headcount  poverty_gap  poverty_severity  watts  mld  gini  polarization  \
# 0       0.67         0.35              0.23   0.64 0.51  0.52          0.46
# 1       0.69         0.33              0.19   0.52 0.31  0.43          0.39
# 2       0.78         0.45              0.30   0.82 0.48  0.51          0.47
# 3       0.48         0.14              0.06   0.18 0.12  0.27          0.24
# 4       0.52         0.16              0.07   0.22 0.16  0.32          0.27
#
#    cpi    ppp  reporting_pop  reporting_gdp
# 0 0.01 107.27       16395477       2,451.51
# 1 0.30 107.27       21695636       4,077.78
# 2 1.23 107.27       30809787       3,595.11
# 3 0.40  50.36        3168033       1,633.55
# 4 0.70  50.36        3051010       2,247.50

# %%
df2005 = df[df['reporting_year'] == 2020]
df2005
# Out:
#                     region_name        country_name  reporting_year  \
# 50    Latin America & Caribbean           Argentina            2020
# 72        Europe & Central Asia             Armenia            2020
# 209       Europe & Central Asia             Belarus            2020
# 239   Latin America & Caribbean             Bolivia            2020
# 275   Latin America & Caribbean              Brazil            2020
# 336   Latin America & Caribbean               Chile            2020
# 441   Latin America & Caribbean            Colombia            2020
# 480   Latin America & Caribbean          Costa Rica            2020
# 595   Latin America & Caribbean  Dominican Republic            2020
# 622   Latin America & Caribbean             Ecuador            2020
# 789       Europe & Central Asia             Georgia            2020
# 1006        East Asia & Pacific           Indonesia            2020
# 1007        East Asia & Pacific           Indonesia            2020
# 1008        East Asia & Pacific           Indonesia            2020
# 1210      Europe & Central Asia     Kyrgyz Republic            2020
# 1376  Latin America & Caribbean              Mexico            2020
# 1617  Latin America & Caribbean                Peru            2020
# 1725  Latin America & Caribbean            Paraguay            2020
# 1801      Europe & Central Asia  Russian Federation            2020
# 1989        East Asia & Pacific            Thailand            2020
# 2082      Europe & Central Asia             Ukraine            2020
# 2110  Latin America & Caribbean             Uruguay            2020
#
#       poverty_line  headcount  poverty_gap  poverty_severity  watts  mld  \
# 50            6.85       0.14         0.05              0.02   0.06 0.32
# 72            6.85       0.53         0.14              0.05   0.18 0.10
# 209           6.85       0.01         0.00              0.00   0.00 0.10
# 239           6.85       0.17         0.07              0.04   0.10 0.35
# 275           6.85       0.19         0.06              0.03   0.09 0.42
# 336           6.85       0.08         0.02              0.01   0.03 0.35
# 441           6.85       0.44         0.21              0.13   0.32 0.55
# 480           6.85       0.20         0.07              0.04   0.10 0.44
# 595           6.85       0.24         0.07              0.03   0.09 0.27
# 622           6.85       0.35         0.14              0.08   0.23 0.41
# 789           6.85       0.58         0.22              0.11   0.33 0.20
# 1006          6.85       0.70         0.28              0.14   0.41 0.16
# 1007          6.85       0.53         0.20              0.10   0.28 0.25
# 1008          6.85       0.61         0.24              0.12   0.34 0.23
# 1210          6.85       0.68         0.23              0.10   0.31 0.14
# 1376          6.85       0.33         0.11              0.06   0.17 0.36
# 1617          6.85       0.43         0.17              0.09   0.27 0.34
# 1725          6.85       0.22         0.07              0.03   0.09 0.32
# 1801          6.85       0.04         0.01              0.00   0.01 0.21
# 1989          6.85       0.13         0.03              0.01   0.03 0.20
# 2082          6.85       0.07         0.01              0.00   0.01 0.11
# 2110          6.85       0.07         0.02              0.01   0.02 0.28
#
#       gini  polarization  cpi      ppp  reporting_pop  reporting_gdp
# 50    0.42          0.41 3.14    10.81       41796990      11,344.41
# 72    0.25          0.20 1.05   167.31        2963234       4,021.05
# 209   0.24          0.20 1.17 6,165.21        9379952       6,234.82
# 239   0.44          0.40 1.05     2.61       11673029       2,983.03
# 275   0.49          0.41 1.11     2.33      212559409       8,228.78
# 336   0.45          0.38 1.09   479.00       19116209      12,954.41
# 441   0.54          0.50 1.10 1,419.37       50882884       5,892.48
# 480   0.49          0.49 1.05   372.67        5094114      12,105.93
# 595   0.40          0.35 1.09    24.39       10847904       7,677.71
# 622   0.47          0.43 0.99     0.57       17643060       5,317.68
# 789   0.34          0.30 1.13     0.92        3714000       4,458.10
# 1006  0.32          0.28 1.08 4,746.85      118597107       3,756.91
# 1007  0.39          0.36 1.08 5,098.20      154926514       3,756.91
# 1008  0.38          0.33 1.08      NaN      273523621       3,756.91
# 1210  0.29          0.24 1.09    19.37        6591600       1,098.09
# 1376  0.45          0.39 1.13     9.86      128932753       8,909.68
# 1617  0.44          0.39 1.05     1.89       32971846       5,792.19
# 1725  0.43          0.39 1.09 2,539.98        7132530       5,670.75
# 1801  0.36          0.30 1.11    25.22      144104080       9,666.81
# 1989  0.35          0.32 1.01    13.29       69799978       6,198.41
# 2082  0.26          0.21 1.23     7.01       44134693       2,344.36
# 2110  0.40          0.37 1.19    24.85        3473727      15,044.64

# %%
df2000.shape
# Out:
# (94, 15)

# %%
df2010
# Out:
#                       region_name          country_name  reporting_year  \
# 2              Sub-Saharan Africa                Angola            2018
# 14          Europe & Central Asia               Albania            2018
# 15          Europe & Central Asia               Albania            2018
# 18    Other High Income Countries  United Arab Emirates            2018
# 48      Latin America & Caribbean             Argentina            2018
# ...                           ...                   ...             ...
# 2048           Sub-Saharan Africa              Tanzania            2018
# 2080        Europe & Central Asia               Ukraine            2018
# 2108    Latin America & Caribbean               Uruguay            2018
# 2141  Other High Income Countries         United States            2018
# 2170          East Asia & Pacific               Vietnam            2018
#
#       poverty_line  headcount  poverty_gap  poverty_severity  watts  mld  \
# 2             3.65       0.53         0.25              0.15   0.40 0.48
# 14            3.65       0.03         0.00              0.00   0.01 0.15
# 15            3.65       0.11         0.04              0.02   0.05 0.23
# 18            3.65       0.00         0.00              0.00   0.00 0.11
# 48            3.65       0.03         0.01              0.00   0.01 0.31
# ...            ...        ...          ...               ...    ...  ...
# 2048          3.65       0.74         0.34              0.18   0.50 0.27
# 2080          3.65       0.00         0.00              0.00   0.00 0.11
# 2108          3.65       0.00         0.00              0.00   0.00 0.27
# 2141          3.65       0.01         0.01              0.01   0.01 0.33
# 2170          3.65       0.05         0.01              0.01   0.02 0.22
#
#       gini  polarization  cpi      ppp  reporting_pop  reporting_gdp
# 2     0.51          0.47 1.23   107.27       30809787       3,595.11
# 14    0.30          0.27 1.02    50.36        2866376       4,431.54
# 15    0.36          0.32 1.02    50.36        2866376       4,431.54
# 18    0.26          0.24 1.03     2.83        9630966      39,670.93
# 48    0.41          0.39 1.49    10.81       40877099      13,105.40
# ...    ...           ...  ...      ...            ...            ...
# 2048  0.40          0.33 1.03   754.62       56313444       1,042.99
# 2080  0.26          0.21 1.11     7.01       44622518       2,336.98
# 2108  0.40          0.36 1.02    24.85        3449290      16,037.93
# 2141  0.41          0.37 1.02     1.00      326838199      59,821.59
# 2170  0.36          0.30 1.02 7,807.61       95545959       2,456.79
#
# [97 rows x 15 columns]

# %%
df.tail()
# Out:
#              region_name country_name  reporting_year  poverty_line  \
# 2204  Sub-Saharan Africa       Zambia            2010          6.85
# 2205  Sub-Saharan Africa       Zambia            2015          6.85
# 2206  Sub-Saharan Africa     Zimbabwe            2011          6.85
# 2207  Sub-Saharan Africa     Zimbabwe            2017          6.85
# 2208  Sub-Saharan Africa     Zimbabwe            2019          6.85
#
#       headcount  poverty_gap  poverty_severity  watts  mld  gini  \
# 2204       0.93         0.70              0.56   1.54 0.54  0.56
# 2205       0.91         0.66              0.52   1.48 0.60  0.57
# 2206       0.78         0.40              0.24   0.66 0.31  0.43
# 2207       0.84         0.49              0.32   0.84 0.32  0.44
# 2208       0.85         0.52              0.36   0.94 0.43  0.50
#
#       polarization  cpi  ppp  reporting_pop  reporting_gdp
# 2204          0.54 0.55 4.22       13605986       1,214.69
# 2205          0.61 0.80 4.22       15879370       1,338.29
# 2206          0.39 0.98 0.49       12894323       1,248.73
# 2207          0.42 1.00 0.49       14236599       1,479.38
# 2208          0.46 1.00 0.49       14645473       1,414.83

# %%
df.shape
# Out:
# (2057, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2057 entries, 0 to 2208
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   region_name       2057 non-null   object
#  1   country_name      2057 non-null   object
#  2   reporting_year    2057 non-null   int64
#  3   poverty_line      2057 non-null   float64
#  4   headcount         2056 non-null   float64
#  5   poverty_gap       2056 non-null   float64
#  6   poverty_severity  2056 non-null   float64
#  7   watts             2056 non-null   float64
#  8   mld               2053 non-null   float64
#  9   gini              2053 non-null   float64
#  10  polarization      2053 non-null   float64
#  11  cpi               2057 non-null   float64
#  12  ppp               2005 non-null   float64
#  13  reporting_pop     2057 non-null   int64
#  14  reporting_gdp     2057 non-null   float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 257.1+ KB

# %% [markdown]
# ### Chequeo de valores nulos

# %%
df.isna().any().any()
# Out:
# True

# %%
df.isna().mean() * 100
# Out:
# region_name        0.00
# country_name       0.00
# reporting_year     0.00
# poverty_line       0.00
# headcount          0.05
# poverty_gap        0.05
# poverty_severity   0.05
# watts              0.05
# mld                0.19
# gini               0.19
# polarization       0.19
# cpi                0.00
# ppp                2.53
# reporting_pop      0.00
# reporting_gdp      0.00
# dtype: float64

# %%
sns.heatmap(df.isna(),yticklabels=False,cmap = "magma")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Como tenemos varios índices, algunos para medir la pobreza y otros para medir la desigualdad, queremos asegurarnos de no analizar variables que tengan una gran correlación

# %%
df = df[df.gini.isna() == False]

# %%
df = df[df.ppp.isna() == False]

# %%
df
# Out:
#                 region_name country_name  reporting_year  poverty_line  \
# 0        Sub-Saharan Africa       Angola            2000          6.85
# 1        Sub-Saharan Africa       Angola            2008          6.85
# 2        Sub-Saharan Africa       Angola            2018          6.85
# 3     Europe & Central Asia      Albania            1996          6.85
# 4     Europe & Central Asia      Albania            2002          6.85
# ...                     ...          ...             ...           ...
# 2204     Sub-Saharan Africa       Zambia            2010          6.85
# 2205     Sub-Saharan Africa       Zambia            2015          6.85
# 2206     Sub-Saharan Africa     Zimbabwe            2011          6.85
# 2207     Sub-Saharan Africa     Zimbabwe            2017          6.85
# 2208     Sub-Saharan Africa     Zimbabwe            2019          6.85
#
#       headcount  poverty_gap  poverty_severity  watts  mld  gini  \
# 0          0.67         0.35              0.23   0.64 0.51  0.52
# 1          0.69         0.33              0.19   0.52 0.31  0.43
# 2          0.78         0.45              0.30   0.82 0.48  0.51
# 3          0.48         0.14              0.06   0.18 0.12  0.27
# 4          0.52         0.16              0.07   0.22 0.16  0.32
# ...         ...          ...               ...    ...  ...   ...
# 2204       0.93         0.70              0.56   1.54 0.54  0.56
# 2205       0.91         0.66              0.52   1.48 0.60  0.57
# 2206       0.78         0.40              0.24   0.66 0.31  0.43
# 2207       0.84         0.49              0.32   0.84 0.32  0.44
# 2208       0.85         0.52              0.36   0.94 0.43  0.50
#
#       polarization  cpi    ppp  reporting_pop  reporting_gdp
# 0             0.46 0.01 107.27       16395477       2,451.51
# 1             0.39 0.30 107.27       21695636       4,077.78
# 2             0.47 1.23 107.27       30809787       3,595.11
# 3             0.24 0.40  50.36        3168033       1,633.55
# 4             0.27 0.70  50.36        3051010       2,247.50
# ...            ...  ...    ...            ...            ...
# 2204          0.54 0.55   4.22       13605986       1,214.69
# 2205          0.61 0.80   4.22       15879370       1,338.29
# 2206          0.39 0.98   0.49       12894323       1,248.73
# 2207          0.42 1.00   0.49       14236599       1,479.38
# 2208          0.46 1.00   0.49       14645473       1,414.83
#
# [2001 rows x 15 columns]

# %% [markdown]
# #### Vamos a filtrar los índices de pobreza y desigualdad para medir su correlatividad

# %%
dfc = df[['poverty_line','headcount','poverty_gap','poverty_severity','watts','mld','gini','polarization','cpi','ppp']]

# %%
corr = dfc.corr()
plt.figure(figsize=(14,14))
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 10},
           xticklabels= dfc.columns, 
           yticklabels= dfc.columns,
           cmap= 'coolwarm')
plt.show()

# %% [markdown]
# #### Vemos que los indicadores de pobreza, en el cuadrante superior izquierdo, tienen alta correlatividad entre sí. Lo mismo ocurre con los indicadores de desigualdad (cuadrado rojo en el medio del gráfico). Vamos a eliminar algunas de estas columnas.

# %% [markdown]
# Los métodos poverty severity y headcount sirven para medir la pobreza, el primero es más elaborado y tiene en cuenta
# cuestiones de desigualdad, mientras que el primero es una simple proporción poblacional. Sin embargo en este trabajo
# no vamos a tener en cuenta estas cuestiones técnicas, priorizaremos no incluir campos con alta correlatividad y que
# pertenezcan a una misma categoría.

# %%
df.drop(columns = ['poverty_gap', 'poverty_severity', 'watts'], inplace = True )

# %%
df.drop(columns = ['mld','polarization'], inplace = True)

# %% [markdown]
# #### La paridad de poder adquisitivo (columna ppp), tiene un valor único para cada país; solo muestra cual es el poder de compra de los ciudadanos de ese país en base 2017. No es un dato que vayamos a utilizar.

# %%
df.drop(columns = 'ppp', inplace= True )

# %%
df.iloc[0:50]
# Out:
#                     region_name          country_name  reporting_year  \
# 0            Sub-Saharan Africa                Angola            2000
# 1            Sub-Saharan Africa                Angola            2008
# 2            Sub-Saharan Africa                Angola            2018
# 3         Europe & Central Asia               Albania            1996
# 4         Europe & Central Asia               Albania            2002
# 5         Europe & Central Asia               Albania            2005
# 6         Europe & Central Asia               Albania            2008
# 7         Europe & Central Asia               Albania            2012
# 8         Europe & Central Asia               Albania            2014
# 9         Europe & Central Asia               Albania            2015
# 10        Europe & Central Asia               Albania            2016
# 11        Europe & Central Asia               Albania            2016
# 12        Europe & Central Asia               Albania            2017
# 13        Europe & Central Asia               Albania            2017
# 14        Europe & Central Asia               Albania            2018
# 15        Europe & Central Asia               Albania            2018
# 16        Europe & Central Asia               Albania            2019
# 17  Other High Income Countries  United Arab Emirates            2013
# 18  Other High Income Countries  United Arab Emirates            2018
# 22    Latin America & Caribbean             Argentina            1991
# 23    Latin America & Caribbean             Argentina            1992
# 24    Latin America & Caribbean             Argentina            1993
# 25    Latin America & Caribbean             Argentina            1994
# 26    Latin America & Caribbean             Argentina            1995
# 27    Latin America & Caribbean             Argentina            1996
# 28    Latin America & Caribbean             Argentina            1997
# 29    Latin America & Caribbean             Argentina            1998
# 30    Latin America & Caribbean             Argentina            1999
# 31    Latin America & Caribbean             Argentina            2000
# 32    Latin America & Caribbean             Argentina            2001
# 33    Latin America & Caribbean             Argentina            2002
# 34    Latin America & Caribbean             Argentina            2003
# 35    Latin America & Caribbean             Argentina            2004
# 36    Latin America & Caribbean             Argentina            2005
# 37    Latin America & Caribbean             Argentina            2006
# 38    Latin America & Caribbean             Argentina            2007
# 39    Latin America & Caribbean             Argentina            2008
# 40    Latin America & Caribbean             Argentina            2009
# 41    Latin America & Caribbean             Argentina            2010
# 42    Latin America & Caribbean             Argentina            2011
# 43    Latin America & Caribbean             Argentina            2012
# 44    Latin America & Caribbean             Argentina            2013
# 45    Latin America & Caribbean             Argentina            2014
# 46    Latin America & Caribbean             Argentina            2016
# 47    Latin America & Caribbean             Argentina            2017
# 48    Latin America & Caribbean             Argentina            2018
# 49    Latin America & Caribbean             Argentina            2019
# 50    Latin America & Caribbean             Argentina            2020
# 51        Europe & Central Asia               Armenia            1996
# 52        Europe & Central Asia               Armenia            1999
#
#     poverty_line  headcount  gini    cpi  reporting_pop  reporting_gdp
# 0           6.85       0.67  0.52   0.01       16395477       2,451.51
# 1           6.85       0.69  0.43   0.30       21695636       4,077.78
# 2           6.85       0.78  0.51   1.23       30809787       3,595.11
# 3           6.85       0.48  0.27   0.40        3168033       1,633.55
# 4           6.85       0.52  0.32   0.70        3051010       2,247.50
# 5           6.85       0.40  0.31   0.75        3011487       2,675.51
# 6           6.85       0.33  0.30   0.82        2947314       3,298.48
# 7           6.85       0.37  0.29   0.92        2900401       3,736.34
# 8           6.85       0.39  0.35   0.95        2889104       3,855.76
# 9           6.85       0.26  0.33   0.98        2880703       3,952.80
# 10          6.85       0.25  0.34   0.98        2876101       4,090.37
# 11          6.85       0.42  0.39   0.98        2876101       4,090.37
# 12          6.85       0.26  0.33   1.00        2873457       4,249.80
# 13          6.85       0.37  0.37   1.00        2873457       4,249.80
# 14          6.85       0.18  0.30   1.02        2866376       4,431.54
# 15          6.85       0.34  0.36   1.02        2866376       4,431.54
# 16          6.85       0.11  0.31   1.03        2854191       4,544.52
# 17          6.85       0.00  0.33   0.92        9197908      35,495.77
# 18          6.85       0.00  0.26   1.03        9630966      39,670.93
# 22          6.85       0.14  0.47 328.91       28887231       8,769.75
# 23          6.85       0.15  0.45   0.04       29352237       9,338.70
# 24          6.85       0.15  0.45   0.04       29809445       9,974.00
# 25          6.85       0.16  0.46   0.04       30260588      10,423.38
# 26          6.85       0.20  0.49   0.04       30705906      10,003.09
# 27          6.85       0.22  0.50   0.04       31145813      10,430.68
# 28          6.85       0.21  0.49   0.05       31579653      11,146.72
# 29          6.85       0.23  0.51   0.05       32009558      11,445.56
# 30          6.85       0.24  0.50   0.04       32438320      10,935.64
# 31          6.85       0.26  0.51   0.04       32867365      10,730.61
# 32          6.85       0.31  0.53   0.04       33297960      10,146.11
# 33          6.85       0.44  0.54   0.06       33728928       8,943.31
# 34          6.85       0.30  0.51   0.06       34159484       9,629.84
# 35          6.85       0.25  0.48   0.07       34588884      10,389.15
# 36          6.85       0.21  0.48   0.07       35015688      11,192.18
# 37          6.85       0.17  0.46   0.08       35439468      11,970.66
# 38          6.85       0.15  0.46   0.10       35861117      12,919.24
# 39          6.85       0.14  0.45   0.13       36284568      13,310.62
# 40          6.85       0.13  0.44   0.14       36714243      12,398.28
# 41          6.85       0.11  0.44   0.18       37055902      13,551.34
# 42          6.85       0.09  0.43   0.22       37543830      14,200.27
# 43          6.85       0.08  0.41   0.27       38027774      13,895.63
# 44          6.85       0.08  0.41   0.34       38509756      14,071.51
# 45          6.85       0.09  0.42   0.48       38990109      13,567.95
# 46          6.85       0.09  0.42   0.85       39940546      13,360.21
# 47          6.85       0.08  0.41   1.05       40410674      13,595.04
# 48          6.85       0.10  0.41   1.49       40877099      13,105.40
# 49          6.85       0.11  0.43   2.28       41339571      12,712.97
# 50          6.85       0.14  0.42   3.14       41796990      11,344.41
# 51          6.85       0.70  0.44   0.42        3168213       1,030.46
# 52          6.85       0.82  0.36   0.53        3089020       1,210.36

# %% [markdown]
# #### Estableceremos una línea divisoria del headcount en 0,2. Es decir que consideraremos país pobre a aquel que tiene al menos a 20 % de su población debajo de la línea de pobreza establecida por la mediana de la mitad superior de los países de medianos ingresos.

# %%
corr = df.corr()
plt.figure(figsize=(14,14))
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 10},
           xticklabels= dfc.columns, 
           yticklabels= dfc.columns,
           cmap= 'coolwarm')
plt.show()
