# %% [markdown]
# # ETL_EDA: net migration by Geographic Regions

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
import warnings

def disable_pandas_warnings():
    warnings.resetwarnings()  # Maybe somebody else is messing with the warnings system?
    warnings.filterwarnings('ignore')  # Ignore everything
    # ignore everything does not work: ignore specific messages, using regex
    warnings.filterwarnings('ignore', '.*A value is trying to be set on a copy of a slice from a DataFrame.*')
    warnings.filterwarnings('ignore', '.indexing past lexsort depth may impact performance')
disable_pandas_warnings()

# %%
df = pd.read_csv('..\\DataSets\\BM\\region\\region_net_migration.csv')

# %%
df
# Out:
#                   country_name country_code  net_migration_1990  \
# 0  AFRICA EASTERN AND SOUTHERN          AFE              22,815
# 1   AFRICA WESTERN AND CENTRAL          AFW            -529,414
# 2          EAST ASIA & PACIFIC          EAS              78,472
# 3        EUROPE & CENTRAL ASIA          ECS             353,755
# 4    LATIN AMERICA & CARIBBEAN          LCN            -635,393
# 5   MIDDLE EAST & NORTH AFRICA          MEA             -99,275
# 6                NORTH AMERICA          NAC           1,566,949
# 7                   SOUTH ASIA          SAS            -765,584
# 8           SUB-SAHARAN AFRICA          SSF            -506,599
# 9                        WORLD          WLD                   0
#
#    net_migration_1991  net_migration_1992  net_migration_1993  \
# 0            -511,160            -556,663            -156,997
# 1            -101,888             -72,380            -345,858
# 2            -928,972            -849,505            -787,093
# 3             413,431              50,409             387,534
# 4            -789,362            -736,813            -799,413
# 5             759,473             -11,230            -984,086
# 6           1,696,571           1,940,175           1,881,649
# 7            -545,640             228,485             796,462
# 8            -613,048            -629,043            -502,855
# 9                   0                   0                   0
#
#    net_migration_1994  net_migration_1995  net_migration_1996  \
# 0            -391,945            -243,945            -427,138
# 1            -198,790              10,350            -188,064
# 2            -567,071            -667,831            -246,490
# 3             -65,762             253,274             113,260
# 4            -727,304            -812,708            -814,722
# 5            -180,184            -142,826              44,978
# 6           1,939,565           1,816,215           1,922,047
# 7             183,479            -225,905            -418,704
# 8            -590,735            -233,595            -615,202
# 9                   0                   0                   0
#
#    net_migration_1997  ...  net_migration_2011  net_migration_2012  \
# 0            -813,478  ...            -683,611            -285,231
# 1              56,467  ...            -198,802            -435,876
# 2            -216,329  ...             465,510             526,680
# 3             -87,120  ...           1,121,738           1,315,534
# 4            -802,462  ...            -495,889            -488,483
# 5             265,402  ...            -344,284             230,635
# 6           2,006,919  ...           1,551,053           1,568,434
# 7            -423,233  ...          -1,412,371          -2,427,962
# 8            -757,011  ...            -882,413            -721,107
# 9                   0  ...                   0                   0
#
#    net_migration_2013  net_migration_2014  net_migration_2015  \
# 0             -92,842            -199,608             394,925
# 1            -377,305            -280,418            -360,393
# 2             448,601             325,445             522,034
# 3           1,196,323           1,504,844           1,514,027
# 4            -535,370            -494,419            -424,043
# 5             550,874             401,511             427,751
# 6           1,563,061           1,446,330           1,454,272
# 7          -2,752,864          -2,708,921          -3,523,806
# 8            -470,147            -480,026              34,532
# 9                   0                   0                   0
#
#    net_migration_2016  net_migration_2017  net_migration_2018  \
# 0            -864,708            -343,075            -366,105
# 1            -167,286            -200,823            -255,888
# 2             539,479             414,719             205,151
# 3           1,586,627           1,026,421           1,142,576
# 4            -139,806            -281,608            -338,149
# 5            -167,117            -175,273             398,806
# 6           1,769,865           1,739,131           1,619,076
# 7          -2,552,785          -2,181,786          -2,409,118
# 8          -1,031,994            -543,898            -621,993
# 9                   0                   0                   0
#
#    net_migration_2019  net_migration_2020
# 0            -187,410             -48,955
# 1            -328,552             -99,761
# 2             232,677             180,870
# 3           1,314,636           1,259,036
# 4            -424,522            -163,087
# 5             119,982          -1,699,850
# 6           1,550,648             871,032
# 7          -2,281,362            -302,152
# 8            -515,962            -148,716
# 9                   0                   0
#
# [10 rows x 33 columns]

# %% [markdown]
# ### We'll eliminate the row 'WORLD' because it's filled with zeros

# %%
df = df[df.country_name != 'WORLD']

# %%
df.describe()
# Out:
#        net_migration_1990  net_migration_1991  net_migration_1992  \
# count                   9                   9                   9
# mean              -57,142             -68,955             -70,729
# std               715,401             867,077             847,753
# min              -765,584            -928,972            -849,505
# 25%              -529,414            -613,048            -629,043
# 50%               -99,275            -511,160             -72,380
# 75%                78,472             413,431              50,409
# max             1,566,949           1,696,571           1,940,175
#
#        net_migration_1993  net_migration_1994  net_migration_1995  \
# count                   9                   9                   9
# mean              -56,740             -66,527             -27,441
# std               930,073             805,076             762,243
# min              -984,086            -727,304            -812,708
# 25%              -787,093            -567,071            -243,945
# 50%              -345,858            -198,790            -225,905
# 75%               387,534             -65,762              10,350
# max             1,881,649           1,939,565           1,816,215
#
#        net_migration_1996  net_migration_1997  net_migration_1998  \
# count                   9                   9                   9
# mean              -70,004             -85,649             -51,049
# std               803,208             876,613             808,368
# min              -814,722            -813,478            -798,462
# 25%              -427,138            -757,011            -453,522
# 50%              -246,490            -216,329            -432,996
# 75%                44,978              56,467             -17,330
# max             1,922,047           2,006,919           1,926,166
#
#        net_migration_1999  ...  net_migration_2011  net_migration_2012  \
# count                   9  ...                   9                   9
# mean              -61,968  ...             -97,674             -79,708
# std               788,061  ...             964,341           1,193,156
# min              -870,278  ...          -1,412,371          -2,427,962
# 25%              -518,744  ...            -683,611            -488,483
# 50%              -299,757  ...            -344,284            -285,231
# 75%               131,492  ...             465,510             526,680
# max             1,811,373  ...           1,551,053           1,568,434
#
#        net_migration_2013  net_migration_2014  net_migration_2015  \
# count                   9                   9                   9
# mean              -52,185             -53,918               4,367
# std             1,254,564           1,251,449           1,489,403
# min            -2,752,864          -2,708,921          -3,523,806
# 25%              -470,147            -480,026            -360,393
# 50%               -92,842            -199,608             394,925
# 75%               550,874             401,511             522,034
# max             1,563,061           1,504,844           1,514,027
#
#        net_migration_2016  net_migration_2017  net_migration_2018  \
# count                   9                   9                   9
# mean             -114,192             -60,688             -69,516
# std             1,333,622           1,092,075           1,150,495
# min            -2,552,785          -2,181,786          -2,409,118
# 25%              -864,708            -343,075            -366,105
# 50%              -167,117            -200,823            -255,888
# 75%               539,479             414,719             398,806
# max             1,769,865           1,739,131           1,619,076
#
#        net_migration_2019  net_migration_2020
# count                   9                   9
# mean              -57,763             -16,843
# std             1,116,098             822,791
# min            -2,281,362          -1,699,850
# 25%              -424,522            -163,087
# 50%              -187,410             -99,761
# 75%               232,677             180,870
# max             1,550,648           1,259,036
#
# [8 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 8
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country_name        9 non-null      object
#  1   country_code        9 non-null      object
#  2   net_migration_1990  9 non-null      float64
#  3   net_migration_1991  9 non-null      float64
#  4   net_migration_1992  9 non-null      float64
#  5   net_migration_1993  9 non-null      float64
#  6   net_migration_1994  9 non-null      float64
#  7   net_migration_1995  9 non-null      float64
#  8   net_migration_1996  9 non-null      float64
#  9   net_migration_1997  9 non-null      float64
#  10  net_migration_1998  9 non-null      float64
#  11  net_migration_1999  9 non-null      float64
#  12  net_migration_2000  9 non-null      float64
#  13  net_migration_2001  9 non-null      float64
#  14  net_migration_2002  9 non-null      float64
#  15  net_migration_2003  9 non-null      float64
#  16  net_migration_2004  9 non-null      float64
#  17  net_migration_2005  9 non-null      float64
#  18  net_migration_2006  9 non-null      float64
#  19  net_migration_2007  9 non-null      float64
#  20  net_migration_2008  9 non-null      float64
#  21  net_migration_2009  9 non-null      float64
#  22  net_migration_2010  9 non-null      float64
#  23  net_migration_2011  9 non-null      float64
#  24  net_migration_2012  9 non-null      float64
#  25  net_migration_2013  9 non-null      float64
#  26  net_migration_2014  9 non-null      float64
#  27  net_migration_2015  9 non-null      float64
#  28  net_migration_2016  9 non-null      float64
#  29  net_migration_2017  9 non-null      float64
#  30  net_migration_2018  9 non-null      float64
#  31  net_migration_2019  9 non-null      float64
#  32  net_migration_2020  9 non-null      float64
# dtypes: float64(31), object(2)
# memory usage: 2.4+ KB

# %% [markdown]
# ### Check for null values

# %%
df.isna().any().sum()
# Out:
# 0

# %% [markdown]
# ### Check for duplicates

# %%
dfdups = df[df.duplicated()]

# %%
dfdups
# Out:
# Empty DataFrame
# Columns: [country_name, country_code, net_migration_1990, net_migration_1991, net_migration_1992, net_migration_1993, net_migration_1994, net_migration_1995, net_migration_1996, net_migration_1997, net_migration_1998, net_migration_1999, net_migration_2000, net_migration_2001, net_migration_2002, net_migration_2003, net_migration_2004, net_migration_2005, net_migration_2006, net_migration_2007, net_migration_2008, net_migration_2009, net_migration_2010, net_migration_2011, net_migration_2012, net_migration_2013, net_migration_2014, net_migration_2015, net_migration_2016, net_migration_2017, net_migration_2018, net_migration_2019, net_migration_2020]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# ## Distribution of the migration around the world, by geographic regions.

# %% [markdown]
# ### Histograms

# %% [markdown]
# #### Early 90s

# %%
# Create the plot object
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(16, 16) )

# First subplot 
ax[0,0].hist(df.net_migration_1990, bins=85, color='c')
ax[0,0].set_title("Net migration 1990")
ax[0,0].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
ax[0,0].ticklabel_format(style='plain', axis='y')
ax[0,0].ticklabel_format(style='plain', axis='x')
ax[0,0].set_xticklabels(ax[0,0].get_xticks(), rotation=12)

# Second subplot 
ax[0,1].hist(df.net_migration_1991, bins=85, color='c')
ax[0,1].set_title("Net migration 1991")
ax[0,1].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))   # Helps to remove the scientifc notation
ax[0,1].ticklabel_format(style='plain', axis='y')
ax[0,1].ticklabel_format(style='plain', axis='x')
ax[0,1].set_xticklabels(ax[0,0].get_xticks(), rotation=12)

# Third subplot
ax[1,0].hist(df.net_migration_1992, bins=85, color='c')
ax[1,0].set_title("Net migration 1992")
ax[1,0].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
ax[1,0].ticklabel_format(style='plain', axis='y')
ax[1,0].ticklabel_format(style='plain', axis='x')
ax[1,0].set_xticklabels(ax[0,0].get_xticks(), rotation=12)

# fourth subplot
ax[1,1].hist(df.net_migration_1993, bins=85, color='c')
ax[1,1].set_title("Net migration 1993")
ax[1,1].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))   # Helps to remove the scientifc notation
ax[1,1].ticklabel_format(style='plain', axis='y')
ax[1,1].ticklabel_format(style='plain', axis='x')
ax[1,1].set_xticklabels(ax[0,0].get_xticks(), rotation=12)

# 5
ax[2,0].hist(df.net_migration_1994, bins=85, color='c')
ax[2,0].set_title("Net migration 1994")
ax[2,0].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
ax[2,0].ticklabel_format(style='plain', axis='y')
ax[2,0].ticklabel_format(style='plain', axis='x')
ax[2,0].set_xticklabels(ax[0,0].get_xticks(), rotation=12)

# 6 
ax[2,1].hist(df.net_migration_1995, bins=85, color='c')
ax[2,1].set_title("Net migration 1995")
ax[2,1].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))   # Helps to remove the scientifc notation
ax[2,1].ticklabel_format(style='plain', axis='y')
ax[2,1].ticklabel_format(style='plain', axis='x')
ax[2,1].set_xticklabels(ax[0,0].get_xticks(), rotation=12)


fig.subplots_adjust(hspace=0.5)

# Show the graphs
plt.show()

# %% [markdown]
# There are 9 regions in our dataset. So, whith 85 bins we can almost individualize each region. Although we can't identinfy them, yet.

# %% [markdown]
# #### Late 2010s

# %%
# # Create the plot object
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(14, 16) )

ax[0,0].hist(df.net_migration_2015, bins=85, color='c')
ax[0,0].set_title("Net migration 2015")
ax[0,0].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
ax[0,0].ticklabel_format(style='plain', axis='y')
ax[0,0].ticklabel_format(style='plain', axis='x')
ax[0,0].set_xticklabels(ax[0,0].get_xticks(), rotation=12)

# 6 
ax[0,1].hist(df.net_migration_2016, bins=85, color='c')
ax[0,1].set_title("Net migration 2016")
ax[0,1].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))   # Helps to remove the scientifc notation
ax[0,1].ticklabel_format(style='plain', axis='y')
ax[0,1].ticklabel_format(style='plain', axis='x')
ax[0,1].set_xticklabels(ax[0,0].get_xticks(), rotation=12)

ax[1,0].hist(df.net_migration_2017, bins=85, color='c')
ax[1,0].set_title("Net migration 2017")
ax[1,0].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
ax[1,0].ticklabel_format(style='plain', axis='y')
ax[1,0].ticklabel_format(style='plain', axis='x')
ax[1,0].set_xticklabels(ax[0,0].get_xticks(), rotation=12)


ax[1,1].hist(df.net_migration_2018, bins=85, color='c')
ax[1,1].set_title("Net migration 2018")
ax[1,1].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))   # Helps to remove the scientifc notation
ax[1,1].ticklabel_format(style='plain', axis='y')
ax[1,1].ticklabel_format(style='plain', axis='x')
ax[1,1].set_xticklabels(ax[0,0].get_xticks(), rotation=12)

ax[2,0].hist(df.net_migration_2019, bins=85, color='c')
ax[2,0].set_title("Net migration 2019")
ax[2,0].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
ax[2,0].ticklabel_format(style='plain', axis='y')
ax[2,0].ticklabel_format(style='plain', axis='x')
ax[2,0].set_xticklabels(ax[0,0].get_xticks(), rotation=12)


ax[2,1].hist(df.net_migration_2020, bins=85, color='c')
ax[2,1].set_title("Net migration 2020")
ax[2,1].yaxis.set_major_formatter(ScalarFormatter(useMathText=False))   # Helps to remove the scientifc notation
ax[2,1].ticklabel_format(style='plain', axis='y')
ax[2,1].ticklabel_format(style='plain', axis='x')
ax[2,1].set_xticklabels(ax[0,0].get_xticks(), rotation=12)


# Adjust vertical space between subplots
fig.subplots_adjust(hspace=0.5)

# Show the graphs
plt.show()

# %% [markdown]
# ### Boxplots

# %% [markdown]
# #### 1990s decade

# %%
fig, ax = plt.subplots(figsize = (12,6))
bp1 = ax.boxplot([df.net_migration_1990, df.net_migration_1991, df.net_migration_1992, df.net_migration_1993,
                 df.net_migration_1994, df.net_migration_1995, df.net_migration_1996, df.net_migration_1997,
                  df.net_migration_1998,
                 df.net_migration_1999],
                 patch_artist=True,
                 labels=['1990','1991', '1992', '1993', '1994','1995','1996', '1997', '1998', '1999'])
ax.yaxis.set_tick_params(tickdir='out', length=10)
ax.yaxis.set_ticklabels(['{:,.0f}'.format(y) for y in ax.get_yticks()])

plt.title("Net migration by region in the 90s")
plt.xlabel("year")
plt.ylabel("total")
# Out:
# Text(0, 0.5, 'total')

# %% [markdown]
# #### 2000s decade

# %%
fig, ax = plt.subplots(figsize = (12,6))
bp1 = ax.boxplot([df.net_migration_2000, df.net_migration_2001, df.net_migration_2002, df.net_migration_2003,
                 df.net_migration_2004, df.net_migration_2005, df.net_migration_2006, df.net_migration_2007,
                  df.net_migration_2008, df.net_migration_2009],
                 patch_artist=True,
                 labels=['2000','2001', '2002', '2003', '2004','2005','2006', '2007', '2008', '2009'])
ax.yaxis.set_tick_params(tickdir='out', length=10)
ax.yaxis.set_ticklabels(['{:,.0f}'.format(y) for y in ax.get_yticks()])

plt.title("Net migration by country 2000s")
plt.xlabel("year")
plt.ylabel("total")
# Out:
# Text(0, 0.5, 'total')

# %% [markdown]
# #### 2010-2020

# %%
fig, ax = plt.subplots(figsize = (13,7))
bp1 = ax.boxplot([df.net_migration_2010, df.net_migration_2011, df.net_migration_2012, df.net_migration_2013,
                 df.net_migration_2014, df.net_migration_2015, df.net_migration_2016, df.net_migration_2017,
                  df.net_migration_2018, df.net_migration_2019, df.net_migration_2020],
                 patch_artist=True,
                 labels=['2010','2011', '2012', '2013', '2014','2015','2016', '2017', '2018', '2019','2020'])
ax.yaxis.set_tick_params(tickdir='out', length=10)
ax.yaxis.set_ticklabels(['{:,.0f}'.format(y) for y in ax.get_yticks()])

plt.title("Net migration by region 2010s")
plt.xlabel("year")
plt.ylabel("total")
# Out:
# Text(0, 0.5, 'total')

# %% [markdown]
# ## Regions by net migration

# %% [markdown]
# ### Early 1990s

# %%
filtered = df.sort_values(by=['net_migration_1990'], ascending = False).reset_index(drop=True).iloc[0:10]
countries = filtered.country_name.tolist()
values = filtered.net_migration_1990.tolist()

# %%
# Data
y_pos = [0, 1, 2, 3, 4,5,6,7,8]
performance = values

# Create the plot object
fig, ax = plt.subplots(figsize= (12,6))
ax.barh(y_pos, performance)

# Add labels
ax.set_yticks(y_pos)
ax.set_yticklabels(countries)

# Invert the y axis
ax.invert_yaxis()
# supress scientific notation
ax.ticklabel_format(style='plain', axis='x')
# title
plt.title("top ten net migration 1990")
# plot
plt.show()

# %%
filtered = df.sort_values(by=['net_migration_1991'], ascending = False).reset_index(drop=True).iloc[0:10]
countries = filtered.country_name.tolist()
values = filtered.net_migration_1991.tolist()

# %%
# Data
y_pos = [0, 1, 2, 3, 4,5,6,7,8]
performance = values

# Create the plot object
fig, ax = plt.subplots(figsize= (12,6))
ax.barh(y_pos, performance)

# Add labels
ax.set_yticks(y_pos)
ax.set_yticklabels(countries)

# Invert the y axis
ax.invert_yaxis()
# supress scientific notation
ax.ticklabel_format(style='plain', axis='x')
# title
plt.title("top ten net migration 1991")
# plot
plt.show()

# %%
filtered = df.sort_values(by=['net_migration_1992'], ascending = False).reset_index(drop=True).iloc[0:10]
countries = filtered.country_name.tolist()
values = filtered.net_migration_1992.tolist()

# %%
# Data
y_pos = [0, 1, 2, 3, 4,5,6,7,8]
performance = values

# Create the plot object
fig, ax = plt.subplots(figsize= (12,6))
ax.barh(y_pos, performance)

# Add labels
ax.set_yticks(y_pos)
ax.set_yticklabels(countries)

# Invert the y axis
ax.invert_yaxis()
# supress scientific notation
ax.ticklabel_format(style='plain', axis='x')
# title
plt.title("top ten net migration 1992")
# plot
plt.show()

# %% [markdown]
# ### Middle 2000s

# %%
filtered = df.sort_values(by=['net_migration_2004'], ascending = False).reset_index(drop=True).iloc[0:10]
countries = filtered.country_name.tolist()
values = filtered.net_migration_2004.tolist()

# %%
# Data
y_pos = [0, 1, 2, 3, 4,5,6,7,8]
performance = values

# Create the plot object
fig, ax = plt.subplots(figsize= (12,6))
ax.barh(y_pos, performance)

# Add labels
ax.set_yticks(y_pos)
ax.set_yticklabels(countries)

# Invert the y axis
ax.invert_yaxis()
# supress scientific notation
ax.ticklabel_format(style='plain', axis='x')
# title
plt.title("top ten net migration 2004")
# plot
plt.show()

# %%
filtered = df.sort_values(by=['net_migration_2005'], ascending = False).reset_index(drop=True).iloc[0:10]
countries = filtered.country_name.tolist()
values = filtered.net_migration_2005.tolist()

# %%
# Data
y_pos = [0, 1, 2, 3, 4,5,6,7,8]
performance = values

# Create the plot object
fig, ax = plt.subplots(figsize= (12,6))
ax.barh(y_pos, performance)

# Add labels
ax.set_yticks(y_pos)
ax.set_yticklabels(countries)

# Invert the y axis
ax.invert_yaxis()
# supress scientific notation
ax.ticklabel_format(style='plain', axis='x')
# title
plt.title("top ten net migration 2005")
# plot
plt.show()

# %%
filtered = df.sort_values(by=['net_migration_2006'], ascending = False).reset_index(drop=True).iloc[0:10]
countries = filtered.country_name.tolist()
values = filtered.net_migration_2006.tolist()

# %%
# Data
y_pos = [0, 1, 2, 3, 4,5,6,7,8]
performance = values

# Create the plot object
fig, ax = plt.subplots(figsize= (12,6))
ax.barh(y_pos, performance)

# Add labels
ax.set_yticks(y_pos)
ax.set_yticklabels(countries)

# Invert the y axis
ax.invert_yaxis()
# supress scientific notation
ax.ticklabel_format(style='plain', axis='x')
# title
plt.title("top ten net migration 2006")
# plot
plt.show()

# %% [markdown]
# ### Late 2010s and 2020

# %%
filtered = df.sort_values(by=['net_migration_2018'], ascending = False).reset_index(drop=True).iloc[0:10]
countries = filtered.country_name.tolist()
values = filtered.net_migration_2018.tolist()

# %%
# Data
y_pos = [0, 1, 2, 3, 4,5,6,7,8]
performance = values

# Create the plot object
fig, ax = plt.subplots(figsize= (12,6))
ax.barh(y_pos, performance)

# Add labels
ax.set_yticks(y_pos)
ax.set_yticklabels(countries)

# Invert the y axis
ax.invert_yaxis()
# supress scientific notation
ax.ticklabel_format(style='plain', axis='x')
# title
plt.title("top ten net migration 2018")
# plot
plt.show()

# %%
filtered = df.sort_values(by=['net_migration_2019'], ascending = False).reset_index(drop=True).iloc[0:10]
countries = filtered.country_name.tolist()
values = filtered.net_migration_2019.tolist()

# %%
# Data
y_pos = [0, 1, 2, 3, 4,5,6,7,8]
performance = values

# Create the plot object
fig, ax = plt.subplots(figsize= (12,6))
ax.barh(y_pos, performance)

# Add labels
ax.set_yticks(y_pos)
ax.set_yticklabels(countries)

# Invert the y axis
ax.invert_yaxis()

# supress the scientific notation
ax.ticklabel_format(style='plain', axis='x')

# title
plt.title("top ten net migration 2019")
# plot
plt.show()

# %%
filtered = df.sort_values(by=['net_migration_2020'], ascending = False).reset_index(drop=True).iloc[0:10]
countries = filtered.country_name.tolist()
values = filtered.net_migration_2020.tolist()

# %%
# Data
y_pos = [0, 1, 2, 3, 4,5,6,7,8]
performance = values

# Create the plot object
fig, ax = plt.subplots(figsize= (12,6))
ax.barh(y_pos, performance)

# Add labels
ax.set_yticks(y_pos)
ax.set_yticklabels(countries)

# Invert the y axis
ax.invert_yaxis()
# title
plt.title("top ten net migration 2020")
# plot
plt.show()
