# %% [markdown]
# # Conflictos bélicos y violencia

# %% [markdown]
# - [fuente](https://ucdp.uu.se/)
# - [definiciones](https://www.pcr.uu.se/research/ucdp/definitions/)
# - Programa de Datos de Conflictos de Uppsala
# - Departmento de investigación de la paz y el conflicto de la Universidad Uppsala de Suecia.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
import seaborn as sns
import geopy

# %%
# df = pd.read_csv("dataSetsEDA\\pop_in_poverty.csv", encoding = 'unicode_escape')

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Dataset conflictos

# %%
df = pd.read_csv("dataSets\\GEDEvent.csv",
                   dtype =object, usecols = ['year','date_start', 'date_end','type_of_violence','latitude','longitude',
                                             'geom_wkt','country',"side_a","side_b","deaths_a",'deaths_b',
                                             'deaths_civilians','deaths_unknown','best','high']
                  )

# %% [markdown]
# Explicación: Sundberg, Ralph, and Erik Melander, 2013, “Introducing the UCDP Georeferenced Event Dataset”, Journal of Peace Research, vol.50, no.4, 6
#
# |type_of_violence| Type of UCDP conflict|
# |----------------|----------------------|
# ||1: state-based conflict|
# ||2: non-state conflict|
# ||3: one-sided violence|

# %%
df
# Out:
#         year type_of_violence                     side_a  \
# 0       2017                1         Government of Iraq
# 1       2021                1         Government of Iraq
# 2       2021                1         Government of Iraq
# 3       2021                1         Government of Iraq
# 4       1989                1  Government of Afghanistan
# ...      ...              ...                        ...
# 293629  1989                3                     Renamo
# 293630  1989                3                     Renamo
# 293631  1990                3                     Renamo
# 293632  1990                3                     Renamo
# 293633  1990                3                     Renamo
#
#                                    side_b    latitude  longitude  \
# 0                                      IS   34.531094  69.162796
# 1                                      IS   34.564444  69.217222
# 2                                      IS   34.428844  70.455750
# 3                                      IS   34.531094  69.162796
# 4       Jam'iyyat-i Islami-yi Afghanistan   34.333330  70.416670
# ...                                   ...         ...        ...
# 293629                          Civilians  -20.500000  32.500000
# 293630                          Civilians  -19.000000  32.500000
# 293631                          Civilians  -18.000000  32.833333
# 293632                          Civilians  -19.000000  32.500000
# 293633                          Civilians  -16.783333  31.583333
#
#                              geom_wkt              country  \
# 0         POINT (69.162796 34.531094)          Afghanistan
# 1       POINT (69.2172222 34.5644444)          Afghanistan
# 2          POINT (70.45575 34.428844)          Afghanistan
# 3         POINT (69.162796 34.531094)          Afghanistan
# 4           POINT (70.41667 34.33333)          Afghanistan
# ...                               ...                  ...
# 293629             POINT (32.5 -20.5)  Zimbabwe (Rhodesia)
# 293630               POINT (32.5 -19)  Zimbabwe (Rhodesia)
# 293631          POINT (32.833333 -18)  Zimbabwe (Rhodesia)
# 293632               POINT (32.5 -19)  Zimbabwe (Rhodesia)
# 293633   POINT (31.583333 -16.783333)  Zimbabwe (Rhodesia)
#
#                      date_start                 date_end deaths_a deaths_b  \
# 0       2017-07-31 00:00:00.000  2017-07-31 00:00:00.000        0        4
# 1       2021-08-26 00:00:00.000  2021-08-26 00:00:00.000       13        1
# 2       2021-08-28 00:00:00.000  2021-08-28 00:00:00.000        0        2
# 3       2021-08-29 00:00:00.000  2021-08-29 00:00:00.000        0        0
# 4       1989-01-07 00:00:00.000  1989-01-13 00:00:00.000        6        0
# ...                         ...                      ...      ...      ...
# 293629  1989-03-18 00:00:00.000  1989-03-24 00:00:00.000        0        0
# 293630  1989-07-09 00:00:00.000  1989-07-15 00:00:00.000        0        0
# 293631  1990-06-07 00:00:00.000  1990-06-10 00:00:00.000        0        0
# 293632  1990-11-17 00:00:00.000  1990-11-23 00:00:00.000        0        0
# 293633  1990-11-25 00:00:00.000  1990-11-25 00:00:00.000        0        0
#
#        deaths_civilians deaths_unknown best high
# 0                     0              2    6    6
# 1                   141             28  183  184
# 2                     0              0    2    3
# 3                    10              0   10   10
# 4                     0              0    6    6
# ...                 ...            ...  ...  ...
# 293629                9              0    9    9
# 293630                9              0    9    9
# 293631                7              0    7    7
# 293632                1              0    1    1
# 293633                6              0    6    6
#
# [293634 rows x 16 columns]

# %%
len(df[df.duplicated()])
# Out:
# 4598

# %%
prct_duplicados = round((len(df[df.duplicated()])/len(df)) *100,2)
prct_duplicados
# Out:
# 1.57

# %%
# Eliminamos los registros duplicados 
df = df.drop_duplicates()

# %%
df
# Out:
#         year type_of_violence                     side_a  \
# 0       2017                1         Government of Iraq
# 1       2021                1         Government of Iraq
# 2       2021                1         Government of Iraq
# 3       2021                1         Government of Iraq
# 4       1989                1  Government of Afghanistan
# ...      ...              ...                        ...
# 293629  1989                3                     Renamo
# 293630  1989                3                     Renamo
# 293631  1990                3                     Renamo
# 293632  1990                3                     Renamo
# 293633  1990                3                     Renamo
#
#                                    side_b    latitude  longitude  \
# 0                                      IS   34.531094  69.162796
# 1                                      IS   34.564444  69.217222
# 2                                      IS   34.428844  70.455750
# 3                                      IS   34.531094  69.162796
# 4       Jam'iyyat-i Islami-yi Afghanistan   34.333330  70.416670
# ...                                   ...         ...        ...
# 293629                          Civilians  -20.500000  32.500000
# 293630                          Civilians  -19.000000  32.500000
# 293631                          Civilians  -18.000000  32.833333
# 293632                          Civilians  -19.000000  32.500000
# 293633                          Civilians  -16.783333  31.583333
#
#                              geom_wkt              country  \
# 0         POINT (69.162796 34.531094)          Afghanistan
# 1       POINT (69.2172222 34.5644444)          Afghanistan
# 2          POINT (70.45575 34.428844)          Afghanistan
# 3         POINT (69.162796 34.531094)          Afghanistan
# 4           POINT (70.41667 34.33333)          Afghanistan
# ...                               ...                  ...
# 293629             POINT (32.5 -20.5)  Zimbabwe (Rhodesia)
# 293630               POINT (32.5 -19)  Zimbabwe (Rhodesia)
# 293631          POINT (32.833333 -18)  Zimbabwe (Rhodesia)
# 293632               POINT (32.5 -19)  Zimbabwe (Rhodesia)
# 293633   POINT (31.583333 -16.783333)  Zimbabwe (Rhodesia)
#
#                      date_start                 date_end deaths_a deaths_b  \
# 0       2017-07-31 00:00:00.000  2017-07-31 00:00:00.000        0        4
# 1       2021-08-26 00:00:00.000  2021-08-26 00:00:00.000       13        1
# 2       2021-08-28 00:00:00.000  2021-08-28 00:00:00.000        0        2
# 3       2021-08-29 00:00:00.000  2021-08-29 00:00:00.000        0        0
# 4       1989-01-07 00:00:00.000  1989-01-13 00:00:00.000        6        0
# ...                         ...                      ...      ...      ...
# 293629  1989-03-18 00:00:00.000  1989-03-24 00:00:00.000        0        0
# 293630  1989-07-09 00:00:00.000  1989-07-15 00:00:00.000        0        0
# 293631  1990-06-07 00:00:00.000  1990-06-10 00:00:00.000        0        0
# 293632  1990-11-17 00:00:00.000  1990-11-23 00:00:00.000        0        0
# 293633  1990-11-25 00:00:00.000  1990-11-25 00:00:00.000        0        0
#
#        deaths_civilians deaths_unknown best high
# 0                     0              2    6    6
# 1                   141             28  183  184
# 2                     0              0    2    3
# 3                    10              0   10   10
# 4                     0              0    6    6
# ...                 ...            ...  ...  ...
# 293629                9              0    9    9
# 293630                9              0    9    9
# 293631                7              0    7    7
# 293632                1              0    1    1
# 293633                6              0    6    6
#
# [289036 rows x 16 columns]

# %% [markdown]
# #### Chequear valores nulos

# %%
df.isna().mean() * 100
# Out:
# year               0.00
# type_of_violence   0.00
# side_a             0.00
# side_b             0.00
# latitude           0.00
# longitude          0.00
# geom_wkt           0.00
# country            0.00
# date_start         0.00
# date_end           0.00
# deaths_a           0.00
# deaths_b           0.00
# deaths_civilians   0.00
# deaths_unknown     0.00
# best               0.00
# high               0.00
# dtype: float64

# %%
df.columns
# Out:
# Index(['year', 'type_of_violence', 'side_a', 'side_b', 'latitude', 'longitude',
#        'geom_wkt', 'country', 'date_start', 'date_end', 'deaths_a', 'deaths_b',
#        'deaths_civilians', 'deaths_unknown', 'best', 'high'],
#       dtype='object')

# %%
df.country.value_counts()
# Out:
# Syria                 84198
# Afghanistan           41345
# India                 16514
# Mexico                10371
# Bosnia-Herzegovina     8309
#                       ...
# Italy                     1
# Benin                     1
# Qatar                     1
# Botswana                  1
# Malta                     1
# Name: country, Length: 123, dtype: int64

# %%
df.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belgium', 'Benin', 'Bhutan', 'Bolivia',
#        'Bosnia-Herzegovina', 'Botswana', 'Brazil', 'Burkina Faso',
#        'Burundi', 'Cambodia (Kampuchea)', 'Cameroon', 'Canada',
#        'Central African Republic', 'Chad', 'China', 'Colombia', 'Comoros',
#        'Congo', 'Croatia', 'Djibouti', 'DR Congo (Zaire)', 'Ecuador',
#        'Egypt', 'El Salvador', 'Eritrea', 'Ethiopia', 'France', 'Gambia',
#        'Georgia', 'Germany', 'Ghana', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Israel', 'Italy', 'Ivory Coast',
#        'Jamaica', 'Jordan', 'Kenya', 'Kingdom of eSwatini (Swaziland)',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Macedonia, FYR', 'Madagascar (Malagasy)', 'Malaysia',
#        'Mali', 'Malta', 'Mauritania', 'Mexico', 'Moldova', 'Morocco',
#        'Mozambique', 'Myanmar (Burma)', 'Namibia', 'Nepal', 'Netherlands',
#        'Nicaragua', 'Niger', 'Nigeria', 'Pakistan', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Qatar',
#        'Romania', 'Russia (Soviet Union)', 'Rwanda', 'Saudi Arabia',
#        'Senegal', 'Serbia (Yugoslavia)', 'Sierra Leone',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
#        'Spain', 'Sri Lanka', 'Sudan', 'Sweden', 'Syria', 'Tajikistan',
#        'Tanzania', 'Thailand', 'Togo', 'Trinidad and Tobago', 'Tunisia',
#        'Turkey', 'Uganda', 'Ukraine', 'United Arab Emirates',
#        'United Kingdom', 'United States of America', 'Uzbekistan',
#        'Venezuela', 'Yemen (North Yemen)', 'Zambia',
#        'Zimbabwe (Rhodesia)'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 289036 entries, 0 to 293633
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   year              289036 non-null  object
#  1   type_of_violence  289036 non-null  object
#  2   side_a            289036 non-null  object
#  3   side_b            289036 non-null  object
#  4   latitude          289036 non-null  object
#  5   longitude         289036 non-null  object
#  6   geom_wkt          289036 non-null  object
#  7   country           289036 non-null  object
#  8   date_start        289036 non-null  object
#  9   date_end          289036 non-null  object
#  10  deaths_a          289036 non-null  object
#  11  deaths_b          289036 non-null  object
#  12  deaths_civilians  289036 non-null  object
#  13  deaths_unknown    289036 non-null  object
#  14  best              289036 non-null  object
#  15  high              289036 non-null  object
# dtypes: object(16)
# memory usage: 37.5+ MB

# %% [markdown]
# #### Cambiar el tipo de dato

# %%
df = df.copy()

# %%
df.year = df['year'].astype('int')
df.type_of_violence == df.type_of_violence.astype('int')
df.best = df['best'].astype('int')
df.high = df['high'].astype('int')

# %%
df.latitude = df.latitude.astype('float')
df.longitude = df.longitude.astype('float')

# %% [markdown]
# #### Filtrar por año

# %%
df = df[df.year >= 1990].copy()

# %%
df = df[df.year < 2021].copy()

# %%
df
# Out:
#         year type_of_violence                             side_a  \
# 0       2017                1                 Government of Iraq
# 55      1990                1          Government of Afghanistan
# 56      1990                1          Government of Afghanistan
# 57      1990                1          Government of Afghanistan
# 58      1990                1          Government of Afghanistan
# ...      ...              ...                                ...
# 293627  2019                3  Government of Zimbabwe (Rhodesia)
# 293628  2020                3  Government of Zimbabwe (Rhodesia)
# 293631  1990                3                             Renamo
# 293632  1990                3                             Renamo
# 293633  1990                3                             Renamo
#
#                                    side_b  latitude  longitude  \
# 0                                      IS     34.53      69.16
# 55      Jam'iyyat-i Islami-yi Afghanistan     34.55      68.94
# 56      Jam'iyyat-i Islami-yi Afghanistan     34.18      62.76
# 57      Jam'iyyat-i Islami-yi Afghanistan     34.53      69.16
# 58      Jam'iyyat-i Islami-yi Afghanistan     34.53      69.16
# ...                                   ...       ...        ...
# 293627                          Civilians    -21.36      30.71
# 293628                          Civilians    -17.93      25.83
# 293631                          Civilians    -18.00      32.83
# 293632                          Civilians    -19.00      32.50
# 293633                          Civilians    -16.78      31.58
#
#                             geom_wkt              country  \
# 0        POINT (69.162796 34.531094)          Afghanistan
# 55       POINT (68.936374 34.548073)          Afghanistan
# 56       POINT (62.756055 34.183466)          Afghanistan
# 57       POINT (69.162796 34.531094)          Afghanistan
# 58       POINT (69.162796 34.531094)          Afghanistan
# ...                              ...                  ...
# 293627    POINT (30.70668 -21.35838)  Zimbabwe (Rhodesia)
# 293628    POINT (25.83066 -17.93285)  Zimbabwe (Rhodesia)
# 293631         POINT (32.833333 -18)  Zimbabwe (Rhodesia)
# 293632              POINT (32.5 -19)  Zimbabwe (Rhodesia)
# 293633  POINT (31.583333 -16.783333)  Zimbabwe (Rhodesia)
#
#                      date_start                 date_end deaths_a deaths_b  \
# 0       2017-07-31 00:00:00.000  2017-07-31 00:00:00.000        0        4
# 55      1990-04-01 00:00:00.000  1990-07-09 00:00:00.000       50      100
# 56      1990-04-06 00:00:00.000  1990-04-06 00:00:00.000        2        2
# 57      1990-07-11 00:00:00.000  1990-07-11 00:00:00.000        0        8
# 58      1990-07-13 00:00:00.000  1990-07-15 00:00:00.000        0       15
# ...                         ...                      ...      ...      ...
# 293627  2019-12-26 00:00:00.000  2019-12-26 00:00:00.000        0        0
# 293628  2020-09-30 00:00:00.000  2020-09-30 00:00:00.000        0        0
# 293631  1990-06-07 00:00:00.000  1990-06-10 00:00:00.000        0        0
# 293632  1990-11-17 00:00:00.000  1990-11-23 00:00:00.000        0        0
# 293633  1990-11-25 00:00:00.000  1990-11-25 00:00:00.000        0        0
#
#        deaths_civilians deaths_unknown  best  high
# 0                     0              2     6     6
# 55                    0            300   450  1100
# 56                    3             13    20    20
# 57                    0              0     8     8
# 58                    0              0    15    15
# ...                 ...            ...   ...   ...
# 293627                2              0     2     2
# 293628                2              0     2     2
# 293631                7              0     7     7
# 293632                1              0     1     1
# 293633                6              0     6     6
#
# [270762 rows x 16 columns]

# %% [markdown]
# #### volver a chequear nulos

# %%
df.isna().mean()*100
# Out:
# year               0.00
# type_of_violence   0.00
# side_a             0.00
# side_b             0.00
# latitude           0.00
# longitude          0.00
# geom_wkt           0.00
# country            0.00
# date_start         0.00
# date_end           0.00
# deaths_a           0.00
# deaths_b           0.00
# deaths_civilians   0.00
# deaths_unknown     0.00
# best               0.00
# high               0.00
# dtype: float64

# %%
df.best.sum()
# Out:
# 2666962

# %%
df['high'].sum()
# Out:
# 4129446

# %%
df.high.describe()
# Out:
# count   270,762.00
# mean         15.25
# std         349.01
# min           0.00
# 25%           1.00
# 50%           2.00
# 75%           6.00
# max      75,000.00
# Name: high, dtype: float64

# %% [markdown]
# #### Vamos a eliminar los campos que no vamos a utilizar en nuestro análisis

# %%
df.columns
# Out:
# Index(['year', 'type_of_violence', 'side_a', 'side_b', 'latitude', 'longitude',
#        'geom_wkt', 'country', 'date_start', 'date_end', 'deaths_a', 'deaths_b',
#        'deaths_civilians', 'deaths_unknown', 'best', 'high'],
#       dtype='object')

# %%
# No analizaremos los países o bandos envueltos en los conflictos, tampoco las fechas de inicio y de final
df.drop(columns = ['side_a', 'side_b','date_start', 'date_end', 'deaths_a', 'deaths_b',
       'deaths_civilians', 'deaths_unknown'], inplace = True)

# %%
dfc = df[['year', 'type_of_violence', 'latitude', 'longitude', 'best', 'high']]

# %%
corr = dfc.corr(numeric_only = True)
plt.figure(figsize=(11,11))
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 10},
           xticklabels= dfc.columns, 
           yticklabels= dfc.columns,
           cmap= 'coolwarm')
plt.show()

# %%
df['year'].unique()
# Out:
# array([2017, 1990, 1991, 1992, 1996, 1993, 1994, 1995, 2002, 2003, 2006,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2016, 2004, 2005, 2007,
#        2015, 2018, 2019, 2020, 1997, 1998, 1999, 2000, 2001])

# %% [markdown]
# Sacamos los años posteriores a 2020, que es el límite de nuestro análisis

# %%
df = df[df['year']<2021]

# %%
df['type_of_violence'] = df['type_of_violence'].astype(int)

# %%
df.groupby(['country', 'year'])['type_of_violence'].value_counts()
# Out:
# country              year  type_of_violence
# Afghanistan          1990  1                   39
#                            2                    6
#                      1991  1                   60
#                            2                    4
#                      1992  1                   69
#                                                ..
# Zimbabwe (Rhodesia)  2011  3                    1
#                      2012  3                    1
#                      2018  3                    2
#                      2019  3                    7
#                      2020  3                    1
# Name: type_of_violence, Length: 3179, dtype: int64

# %%
df.type_of_violence.value_counts()
# Out:
# 1    200301
# 3     41120
# 2     29341
# Name: type_of_violence, dtype: int64

# %%
sns.set(rc = {'figure.figsize':(8,10)}, font_scale=0.5)
sns.lineplot(x = 'year',
            y = 'country',
            hue = 'type_of_violence',
            data = df,
            errorbar = None)
 
# Show the plot
plt.show()

# %%
sns.relplot(data=df, x="best", y="type_of_violence", hue='year')
plt.show()

# %%
sns.relplot(data=df, x="high", y="type_of_violence", hue='year')
plt.show()

# %%
sns.lineplot(x = 'year',
            y = 'best',
            hue = 'type_of_violence',
            data = df,
            errorbar = None)
 
# Show the plot
plt.show()

# %%
sns.lineplot(x = 'year',
            y = 'high',
            hue = 'type_of_violence',
            data = df,
            errorbar = None)
 
# Show the plot
plt.show()

# %%
sns.set(rc = {'figure.figsize':(10,15)}, font_scale=0.5)
sns.lineplot(x = 'best',
            y = 'country',
            hue = 'type_of_violence',
            data = df,
            errorbar = None)
 
# Show the plot
plt.show()

# %% [markdown]
# ## Vamos a normalizar los datos

# %% [markdown]
# ### Cambiamos el tipo de dato de la columna year

# %%
df['year'] = pd.to_datetime(df['year'], format='%Y')

# %% [markdown]
# ### Comencemos con los nombres de países, queremos dejar solo los nombres actuales y/o los asignados por los investigadores de nuestra fuente de datos.

# %%
# creamos un objeto SRE_Pattern con el siguiente patrón, espacio en blanco seguido de paréntesis con
# "cualquier dato" dentro de estos.
def remover_paréntesis(string):
    pattern = re.compile(r"\s*\(.*?\)")
    country = string
    country = pattern.sub("", country)
    
    return country

# %%
df2 = df.copy()

# %%
df.country = df.country.apply(lambda x: remover_paréntesis(x))

# %% [markdown]
# #### Vamos a llevar todos los nombres a letras mayúsculas para igualar el trabajo en todos los datasets

# %%
df.country = df.country.apply(lambda x: x.upper())

# %% [markdown]
# #### También debemos cambiar el nombre de la columna

# %%
df.rename(columns = {'country' : 'country_name'}, inplace = True)

# %% [markdown]
# ### Ahora, usemos nuestro estandar para igualar los nombres de países

# %%
est = pd.read_csv('dataSets\\estandar_paises_regiones.csv', usecols =['country_name'])

# %%
# guardamos los valores únicos de los nombres de países de cada data frame
paisesdf = set(df['country_name'])
paises_est = set(est['country_name'])

# %%
# Identificamos el dataframe con menos países (debería ser el data frame principal de este notebook)
if len(paisesdf) <= len(paises_est):
    df_menos_paises = df
    df_mas_paises = est
else:
    df_menos_paises = est
    df_mas_paises = df

# %%
# Obtenemos los nombres únicos de países en el dataframe con menos nombres
paises_menos = set(df_menos_paises['country_name'])

# %%
# Obtenemos los nombres únicos de países en el dataframe con más nombres
paises_mas = set(df_mas_paises['country_name'])

# %%
# Obtener nombres únicos de países que están en el dataframe con menos nombres y no en el dataframe con más nombres
paises_no_comunes = paises_menos.difference(paises_mas)

# %% [markdown]
# #### Los siguientes nombres tienen que ser reemplazados en el dataframe df

# %%
paises_no_comunes
# Out:
# {'BOSNIA-HERZEGOVINA',
#  'DR CONGO',
#  'IVORY COAST',
#  'KINGDOM OF ESWATINI',
#  'MACEDONIA, FYR',
#  'SYRIA',
#  'TURKEY',
#  'UNITED STATES OF AMERICA'}

# %%
reemplazos = {'BOSNIA-HERZEGOVINA': 'BOSNIA AND HERZEGOVINA',
              'DR CONGO': 'DEMOCRATIC REPUBLIC OF THE CONGO', 
              'IVORY COAST' :'CÔTE D’IVOIRE',
              'KINGDOM OF ESWATINI':'ESWATINI',
              'MACEDONIA, FYR': 'NORTH MACEDONIA',
              'SYRIA': 'SYRIAN ARAB REPUBLIC',
              'TURKEY':'TÜRKIYE',
             'UNITED STATES OF AMERICA': 'UNITED STATES'}

# %%
df.country_name = df.country_name.replace(reemplazos)

# %% [markdown]
# #### Chequeamos que los nombres hayan sido substituídos, no debería haber diferencias entre ambos sets, por lo tanto deberíamosobtener un set vacío

# %%
paises_menos = set(df_menos_paises['country_name'])
paises_mas = set(df_mas_paises['country_name'])
paises_no_comunes = paises_menos.difference(paises_mas)
paises_no_comunes
# Out:
# set()

# %%
df.to_csv('dataSets\\conflictos_final.csv', index = False)
